# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
# Plotly libraries
import plotly
import plotly.express as px
import plotly.graph_objs as go


# Measuring run time
from time import time

# Text preprocessing/analysis
import nltk
import re, random
from nltk import word_tokenize, sent_tokenize, pos_tag
from nltk.util import ngrams
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from spellchecker import SpellChecker

from math import log2

# %%
stop_words = set(stopwords.words('english'))

# %%
data = pd.read_csv('https://raw.githubusercontent.com/susanli2016/NLP-with-Python/master/data/title_conference.csv')
data.shape
# Out:
# (2507, 2)

# %%
data.head()
# Out:
#                                                Title Conference
# 0  Innovation in Database Management: Computer Sc...       VLDB
# 1  High performance prime field multiplication fo...      ISCAS
# 2  enchanted scissors: a scissor interface for su...   SIGGRAPH
# 3  Detection of channel degradation attack by Int...    INFOCOM
# 4  Pinning a Complex Network through the Betweenn...      ISCAS

# %% [markdown]
# # Data Preprocessing

# %%
def lemmatize_text(text):
    tokeniser = RegexpTokenizer(r'[A-Za-z]+')
    tokens = tokeniser.tokenize(text)
    # 2. POS tagging
    pos_map = {'J': 'a', 'N': 'n', 'R': 'r', 'V': 'v'}
    pos_tags = pos_tag(tokens)
    print(pos_tags)
    # 3. Lowercase and lemmatise 
    lemmatiser = WordNetLemmatizer()
    return ' '.join([lemmatiser.lemmatize(t.lower(), pos=pos_map.get(p[0], 'v'))  for t, p in pos_tags if p not in ['DT', 'IN']])

# %%
data['Title']=data.Title.apply(lemmatize_text)
# Out:
# [('Innovation', 'NN'), ('in', 'IN'), ('Database', 'NNP'), ('Management', 'NNP'), ('Computer', 'NNP'), ('Science', 'NNP'), ('vs', 'NN'), ('Engineering', 'VBG')]
# [('High', 'JJ'), ('performance', 'NN'), ('prime', 'JJ'), ('field', 'NN'), ('multiplication', 'NN'), ('for', 'IN'), ('GPU', 'NNP')]
# [('enchanted', 'VBN'), ('scissors', 'NNS'), ('a', 'DT'), ('scissor', 'NN'), ('interface', 'NN'), ('for', 'IN'), ('support', 'NN'), ('in', 'IN'), ('cutting', 'VBG'), ('and', 'CC'), ('interactive', 'JJ'), ('fabrication', 'NN')]
# [('Detection', 'NN'), ('of', 'IN'), ('channel', 'NN'), ('degradation', 'NN'), ('attack', 'NN'), ('by', 'IN'), ('Intermediary', 'NNP'), ('Node', 'NNP'), ('in', 'IN'), ('Linear', 'NNP'), ('Networks', 'NNP')]
# [('Pinning', 'VBG'), ('a', 'DT'), ('Complex', 'JJ'), ('Network', 'NNP'), ('through', 'IN'), ('the', 'DT'), ('Betweenness', 'NNP'), ('Centrality', 'NNP'), ('Strategy', 'NNP')]
# [('Analysis', 'NN'), ('and', 'CC'), ('Design', 'NNP'), ('of', 'IN'), ('Memoryless', 'NNP'), ('Interconnect', 'NNP'), ('Encoding', 'NNP'), ('Scheme', 'NNP')]
# [('Dynamic', 'NNP'), ('bluescreens', 'NNS')]
# [('A', 'DT'), ('Quantitative', 'JJ'), ('Assured', 'NNP'), ('Forwarding', 'NNP'), ('Service', 'NNP')]
# [('Automatic', 'JJ'), ('sanitization', 'NN'), ('of', 'IN'), ('social', 'JJ'), ('network', 'NN'), ('data', 'NNS'), ('to', 'TO'), ('prevent', 'VB'), ('inference', 'NN'), ('attacks', 'NNS')]
# [('A', 'DT'), ('IR', 'NNP'), ('UWB', 'NNP'), ('radar', 'NN'), ('with', 'IN'), ('sub', 'JJ'), ('mm', 'NN'), ('ranging', 'VBG'), ('capability', 'NN'), ('for', 'IN'), ('human', 'JJ'), ('body', 'NN'), ('monitoring', 'VBG'), ('systems', 'NNS')]
# [('Architecture', 'NN'), ('of', 'IN'), ('a', 'DT'), ('multi', 'NN'), ('slot', 'NN'), ('main', 'JJ'), ('memory', 'NN'), ('system', 'NN'), ('for', 'IN'), ('Gbps', 'NNP'), ('operation', 'NN')]
# [('Rule', 'NNP'), ('based', 'VBN'), ('Service', 'NNP'), ('Customization', 'NNP'), ('via', 'IN'), ('Houdini', 'NNP')]
# [('Business', 'NN'), ('Policy', 'NN'), ('Modeling', 'NNP'), ('and', 'CC'), ('Enforcement', 'NNP'), ('in', 'IN'), ('Databases', 'NNP')]
# [('A', 'DT'), ('high', 'JJ'), ('speed', 'NN'), ('and', 'CC'), ('high', 'JJ'), ('linearity', 'NN'), ('OTA', 'NNP'), ('in', 'IN'), ('V', 'NNP'), ('power', 'NN'), ('supply', 'NN'), ('voltage', 'NN')]
# [('PREDIcT', 'NNP'), ('Towards', 'NNP'), ('Predicting', 'VBG'), ('the', 'DT'), ('Runtime', 'NNP'), ('of', 'IN'), ('Large', 'NNP'), ('Scale', 'NNP'), ('Iterative', 'NNP'), ('Analytics', 'NNS')]
# [('SocialSensor', 'NNP'), ('sensing', 'VBG'), ('user', 'RB'), ('generated', 'VBN'), ('input', 'NN'), ('for', 'IN'), ('improved', 'JJ'), ('media', 'NNS'), ('discovery', 'NN'), ('and', 'CC'), ('experience', 'NN')]
# [('Parametric', 'NNP'), ('keyframe', 'NN'), ('interpolation', 'NN'), ('incorporating', 'VBG'), ('kinetic', 'JJ'), ('adjustment', 'NN'), ('and', 'CC'), ('phrasing', 'NN'), ('control', 'NN')]
# [('An', 'DT'), ('Explanation', 'NN'), ('for', 'IN'), ('Unexpected', 'NNP'), ('Outdoor', 'NNP'), ('Link', 'NNP'), ('level', 'NN'), ('Measurement', 'NNP'), ('Results', 'NNP')]
# [('Hot', 'NNP'), ('Block', 'NNP'), ('Clustering', 'NNP'), ('for', 'IN'), ('Disk', 'NNP'), ('Arrays', 'NNP'), ('with', 'IN'), ('Dynamic', 'NNP'), ('Striping', 'VBG')]
# [('Analysis', 'NN'), ('of', 'IN'), ('propagation', 'NN'), ('delay', 'NN'), ('in', 'IN'), ('D', 'NNP'), ('stacked', 'VBD'), ('DRAM', 'NNP')]
# [('ISHair', 'NNP'), ('importance', 'NN'), ('sampling', 'VBG'), ('for', 'IN'), ('hair', 'NN'), ('scattering', 'VBG')]
# [('Green', 'JJ'), ('Wave', 'NNP'), ('Latency', 'NNP'), ('and', 'CC'), ('Capacity', 'NNP'), ('Efficient', 'NNP'), ('Sleep', 'NNP'), ('Scheduling', 'NNP'), ('for', 'IN'), ('Wireless', 'NNP'), ('Networks', 'NNP')]
# [('Exploiting', 'VBG'), ('innocuous', 'JJ'), ('activity', 'NN'), ('for', 'IN'), ('correlating', 'VBG'), ('users', 'NNS'), ('across', 'IN'), ('sites', 'NNS')]
# [('Optimized', 'NNP'), ('numerical', 'JJ'), ('mapping', 'NN'), ('scheme', 'NN'), ('for', 'IN'), ('filter', 'NN'), ('based', 'VBN'), ('exon', 'JJ'), ('location', 'NN'), ('in', 'IN'), ('DNA', 'NNP'), ('using', 'VBG'), ('a', 'DT'), ('quasi', 'JJ'), ('Newton', 'NNP'), ('algorithm', 'NN')]
# [('Nyquist', 'NNP'), ('criterion', 'NN'), ('based', 'VBN'), ('design', 'NN'), ('of', 'IN'), ('continuous', 'JJ'), ('time', 'NN'), ('Sigma', 'NNP'), ('Delta', 'NNP'), ('modulators', 'NNS')]
# [('Fast', 'NNP'), ('Transient', 'NNP'), ('Simulation', 'NNP'), ('of', 'IN'), ('Lossy', 'NNP'), ('Transmission', 'NNP'), ('Lines', 'NNP')]
# [('Image', 'NN'), ('sensor', 'NN'), ('with', 'IN'), ('focal', 'JJ'), ('plane', 'NN'), ('polarization', 'NN'), ('sensitivity', 'NN')]
# [('Power', 'NN'), ('oriented', 'VBN'), ('delay', 'NN'), ('budgeting', 'VBG'), ('for', 'IN'), ('combinational', 'JJ'), ('circuits', 'NNS')]
# [('Sensor', 'NNP'), ('Network', 'NNP'), ('Navigation', 'NNP'), ('without', 'IN'), ('Locations', 'NNP')]
# [('Simplified', 'NNP'), ('logic', 'JJ'), ('design', 'NN'), ('methodology', 'NN'), ('for', 'IN'), ('fuzzy', 'JJ'), ('membership', 'NN'), ('function', 'NN'), ('based', 'VBN'), ('robust', 'JJ'), ('detection', 'NN'), ('of', 'IN'), ('maternal', 'JJ'), ('modulus', 'NN'), ('maxima', 'NN'), ('location', 'NN'), ('A', 'NNP'), ('low', 'JJ'), ('complexity', 'NN'), ('Fetal', 'NNP'), ('ECG', 'NNP'), ('extraction', 'NN'), ('architecture', 'NN'), ('for', 'IN'), ('mobile', 'JJ'), ('health', 'NN'), ('monitoring', 'NN'), ('systems', 'NNS')]
# [('E', 'NNP'), ('V', 'NNP'), ('Efficient', 'NNP'), ('visual', 'JJ'), ('surveillance', 'NN'), ('with', 'IN'), ('electronic', 'JJ'), ('footprints', 'NNS')]
# [('Analysis', 'NN'), ('of', 'IN'), ('Price', 'NNP'), ('Competition', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('Slotted', 'NNP'), ('Resource', 'NNP'), ('Allocation', 'NNP'), ('Game', 'NNP')]
# [('A', 'DT'), ('language', 'NN'), ('for', 'IN'), ('shading', 'VBG'), ('and', 'CC'), ('lighting', 'VBG'), ('calculations', 'NNS')]
# [('Integration', 'NN'), ('of', 'IN'), ('Streaming', 'NNP'), ('and', 'CC'), ('Elastic', 'NNP'), ('Traffic', 'NNP'), ('in', 'IN'), ('Wireless', 'NNP'), ('Networks', 'NNP')]
# [('MATE', 'NNP'), ('MPLS', 'NNP'), ('Adaptive', 'NNP'), ('Traffic', 'NNP'), ('Engineering', 'NNP')]
# [('Surround', 'NNP'), ('screen', 'NN'), ('projection', 'NN'), ('based', 'VBN'), ('virtual', 'JJ'), ('reality', 'NN'), ('the', 'DT'), ('design', 'NN'), ('and', 'CC'), ('implementation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('CAVE', 'NNP')]
# [('Output', 'NNP'), ('Characteristics', 'NNP'), ('of', 'IN'), ('Class', 'NNP'), ('E', 'NNP'), ('Amplifier', 'NNP'), ('With', 'IN'), ('Nonlinear', 'NNP'), ('Shunt', 'NNP'), ('Capacitance', 'NNP'), ('Versus', 'NNP'), ('Supply', 'NNP'), ('Voltage', 'NNP')]
# [('Predicting', 'VBG'), ('reflectance', 'NN'), ('functions', 'NNS'), ('from', 'IN'), ('complex', 'JJ'), ('surfaces', 'NNS')]
# [('ActionView', 'NNP'), ('a', 'DT'), ('Movement', 'NNP'), ('analysis', 'NN'), ('Ambulatory', 'NNP'), ('Monitor', 'NNP'), ('in', 'IN'), ('Elderly', 'NNP'), ('Homecare', 'NNP'), ('Systems', 'NNPS')]
# [('Live', 'JJ'), ('demonstration', 'NN'), ('Packet', 'NNP'), ('based', 'VBN'), ('AER', 'NNP'), ('with', 'IN'), ('Gevent', 'NNP'), ('s', 'FW'), ('cumulative', 'JJ'), ('throughput', 'NN')]
# [('Adaptive', 'JJ'), ('electricity', 'NN'), ('scheduling', 'NN'), ('in', 'IN'), ('microgrids', 'NNS')]
# [('Design', 'NN'), ('of', 'IN'), ('a', 'DT'), ('bit', 'NN'), ('Low', 'NNP'), ('energy', 'NN'), ('High', 'NNP'), ('performance', 'NN'), ('Adder', 'NNP'), ('using', 'VBG'), ('Dynamic', 'NNP'), ('Feedthrough', 'NNP'), ('Logic', 'NNP')]
# [('Minimax', 'NNP'), ('Design', 'NNP'), ('of', 'IN'), ('IIR', 'NNP'), ('Digital', 'NNP'), ('Filters', 'NNP'), ('using', 'VBG'), ('SDP', 'NNP'), ('Relaxation', 'NNP'), ('Technique', 'NNP')]
# [('Propagation', 'NN'), ('and', 'CC'), ('Reflection', 'NNP'), ('of', 'IN'), ('Phase', 'NNP'), ('Differences', 'NNP'), ('on', 'IN'), ('a', 'DT'), ('Lattice', 'NNP'), ('of', 'IN'), ('Coupled', 'NNP'), ('Oscillators', 'NNS')]
# [('Query', 'DT'), ('Optimization', 'NN'), ('in', 'IN'), ('the', 'DT'), ('Presence', 'NNP'), ('of', 'IN'), ('Foreign', 'NNP'), ('Functions', 'NNP')]
# [('Parallelizing', 'VBG'), ('query', 'NN'), ('optimization', 'NN')]
# [('Optimizing', 'VBG'), ('the', 'DT'), ('Topology', 'NNP'), ('of', 'IN'), ('Bluetooth', 'NNP'), ('Wireless', 'NNP'), ('Personal', 'NNP'), ('Area', 'NNP'), ('Networks', 'NNP')]
# [('A', 'DT'), ('Scalable', 'JJ'), ('Algorithm', 'NNP'), ('for', 'IN'), ('Maximizing', 'NNP'), ('Range', 'NNP'), ('Sum', 'NNP'), ('in', 'IN'), ('Spatial', 'NNP'), ('Databases', 'NNP')]
# [('Coexistence', 'NN'), ('and', 'CC'), ('Transformation', 'NN'), ('of', 'IN'), ('Data', 'NNS')]
# [('Power', 'NN'), ('transfer', 'NN'), ('networks', 'NNS'), ('at', 'IN'), ('RF', 'NNP'), ('frequencies', 'VBZ'), ('new', 'JJ'), ('design', 'NN'), ('procedures', 'NNS'), ('with', 'IN'), ('implementation', 'NN'), ('roadmap', 'NN')]
# [('A', 'DT'), ('distributed', 'VBN'), ('amplifier', 'NN'), ('based', 'VBN'), ('dispersive', 'JJ'), ('delay', 'NN'), ('line', 'NN')]
# [('High', 'JJ'), ('speed', 'NN'), ('front', 'JJ'), ('end', 'NN'), ('for', 'IN'), ('LED', 'NNP'), ('Photodiode', 'NNP'), ('based', 'VBN'), ('fluorescence', 'NN'), ('lifetime', 'NN'), ('measurement', 'NN'), ('system', 'NN')]
# [('Simple', 'JJ'), ('sybil', 'NN'), ('proof', 'NN'), ('mechanisms', 'NN'), ('for', 'IN'), ('multi', 'JJ'), ('level', 'NN'), ('marketing', 'NN')]
# [('Rants', 'NNS'), ('a', 'DT'), ('framework', 'NN'), ('for', 'IN'), ('rank', 'NN'), ('editing', 'NN'), ('and', 'CC'), ('sharing', 'NN'), ('in', 'IN'), ('web', 'JJ'), ('search', 'NN')]
# [('Mobile', 'NNP'), ('search', 'NN'), ('pattern', 'NN'), ('evolution', 'VBP'), ('the', 'DT'), ('trend', 'NN'), ('and', 'CC'), ('the', 'DT'), ('impact', 'NN'), ('of', 'IN'), ('voice', 'NN'), ('queries', 'NNS')]
# [('Data', 'NNP'), ('summaries', 'NNS'), ('for', 'IN'), ('on', 'IN'), ('demand', 'NN'), ('queries', 'NNS'), ('over', 'IN'), ('linked', 'VBN'), ('data', 'NNS')]
# [('Compressive', 'JJ'), ('sampling', 'NN'), ('of', 'IN'), ('EMG', 'NNP'), ('bio', 'NN'), ('signals', 'NNS')]
# [('Anthropocentric', 'NNP'), ('Data', 'NNP'), ('Systems', 'NNP')]
# [('Estimating', 'VBG'), ('clustering', 'VBG'), ('coefficients', 'NNS'), ('and', 'CC'), ('size', 'NN'), ('of', 'IN'), ('social', 'JJ'), ('networks', 'NNS'), ('via', 'IN'), ('random', 'NN'), ('walk', 'NN')]
# [('CALMS', 'NNP'), ('Cloud', 'NNP'), ('assisted', 'VBD'), ('live', 'JJ'), ('media', 'NNS'), ('streaming', 'VBG'), ('for', 'IN'), ('globalized', 'JJ'), ('demands', 'NNS'), ('with', 'IN'), ('time', 'NN'), ('region', 'NN'), ('diversities', 'NNS')]
# [('Quadrature', 'NN'), ('generation', 'NN'), ('techniques', 'NNS'), ('for', 'IN'), ('frequency', 'NN'), ('multiplication', 'NN'), ('based', 'VBN'), ('oscillators', 'NNS')]
# [('Topology', 'NNP'), ('design', 'NN'), ('for', 'IN'), ('fast', 'JJ'), ('convergence', 'NN'), ('of', 'IN'), ('network', 'NN'), ('consensus', 'NN'), ('algorithms', 'NN')]
# [('Analysis', 'NN'), ('of', 'IN'), ('power', 'NN'), ('supply', 'NN'), ('gain', 'NN'), ('of', 'IN'), ('CMOS', 'NNP'), ('bandgap', 'NN'), ('references', 'NNS')]
# [('A', 'DT'), ('Scalable', 'JJ'), ('Method', 'NN'), ('for', 'IN'), ('Access', 'NNP'), ('Control', 'NNP'), ('in', 'IN'), ('Location', 'NNP'), ('Based', 'VBD'), ('Broadcast', 'NNP'), ('Services', 'NNS')]
# [('A', 'DT'), ('novel', 'NN'), ('Fisher', 'NNP'), ('discriminant', 'NN'), ('for', 'IN'), ('biometrics', 'NNS'), ('recognition', 'NN'), ('DPCA', 'NNP'), ('plus', 'CC'), ('DFLD', 'NNP')]
# [('A', 'DT'), ('framework', 'NN'), ('for', 'IN'), ('benchmarking', 'VBG'), ('entity', 'NN'), ('annotation', 'NN'), ('systems', 'NNS')]
# [('A', 'DT'), ('physically', 'RB'), ('based', 'VBN'), ('approach', 'NN'), ('to', 'TO'), ('D', 'NNP'), ('shape', 'NN'), ('blending', 'NN')]
# [('Effects', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('recession', 'NN'), ('on', 'IN'), ('public', 'JJ'), ('mood', 'NN'), ('in', 'IN'), ('the', 'DT'), ('UK', 'NNP')]
# [('GIO', 'VB'), ('a', 'DT'), ('semantic', 'JJ'), ('web', 'NN'), ('application', 'NN'), ('using', 'VBG'), ('the', 'DT'), ('information', 'NN'), ('grid', 'NN'), ('framework', 'NN')]
# [('Maximum', 'JJ'), ('likelihood', 'NN'), ('disjunctive', 'JJ'), ('decomposition', 'NN'), ('to', 'TO'), ('reduced', 'VB'), ('multirooted', 'JJ'), ('DAG', 'NNP'), ('for', 'IN'), ('FIR', 'NNP'), ('filter', 'NN'), ('design', 'NN')]
# [('SocioCrowd', 'VB'), ('a', 'DT'), ('social', 'JJ'), ('network', 'NN'), ('based', 'VBN'), ('framework', 'NN'), ('for', 'IN'), ('crowd', 'JJ'), ('simulation', 'NN')]
# [('A', 'DT'), ('MATLAB', 'NNP'), ('based', 'VBN'), ('optimum', 'JJ'), ('multiband', 'NN'), ('FIR', 'NNP'), ('filters', 'NNS'), ('design', 'VBP'), ('program', 'NN'), ('following', 'VBG'), ('the', 'DT'), ('original', 'JJ'), ('idea', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Remez', 'NNP'), ('multiple', 'JJ'), ('exchange', 'NN'), ('algorithm', 'NN')]
# [('Touchy', 'NNP'), ('Internet', 'NNP'), ('a', 'DT'), ('cybernetics', 'NN'), ('system', 'NN'), ('for', 'IN'), ('human', 'JJ'), ('pet', 'JJ'), ('interaction', 'NN'), ('through', 'IN'), ('the', 'DT'), ('Internet', 'NNP')]
# [('Social', 'NNP'), ('status', 'NN'), ('and', 'CC'), ('role', 'NN'), ('analysis', 'NN'), ('of', 'IN'), ('palin', 'NN'), ('s', 'NN'), ('email', 'NN'), ('network', 'NN')]
# [('A', 'DT'), ('fast', 'JJ'), ('hash', 'NN'), ('tree', 'NN'), ('generator', 'NN'), ('for', 'IN'), ('Merkle', 'NNP'), ('signature', 'NN'), ('scheme', 'NN')]
# [('GPU', 'NNP'), ('Powered', 'NNP'), ('Artificial', 'NNP'), ('Immune', 'NNP'), ('System', 'NNP'), ('for', 'IN'), ('Visual', 'NNP'), ('Applications', 'NNP')]
# [('Linear', 'JJ'), ('combination', 'NN'), ('of', 'IN'), ('transformations', 'NNS')]
# [('GBase', 'NNP'), ('LX', 'NNP'), ('Limiting', 'NNP'), ('Amplifier', 'NNP'), ('in', 'IN'), ('micro', 'NNP'), ('m', 'NN'), ('CMOS', 'NNP'), ('Digital', 'NNP'), ('Process', 'NNP'), ('with', 'IN'), ('Tunable', 'NNP'), ('Shunt', 'NNP'), ('peaking', 'VBG')]
# [('Randomization', 'NN'), ('tests', 'NNS'), ('for', 'IN'), ('distinguishing', 'VBG'), ('social', 'JJ'), ('influence', 'NN'), ('and', 'CC'), ('homophily', 'NN'), ('effects', 'NNS')]
# [('Pricing', 'VBG'), ('algorithms', 'NN'), ('for', 'IN'), ('the', 'DT'), ('day', 'NN'), ('ahead', 'RB'), ('electricity', 'NN'), ('market', 'NN'), ('with', 'IN'), ('flexible', 'JJ'), ('consumer', 'NN'), ('participation', 'NN')]
# [('WS', 'NNP'), ('CatalogNet', 'NNP'), ('An', 'DT'), ('Infrastructure', 'NN'), ('for', 'IN'), ('Creating', 'VBG'), ('Peering', 'NNP'), ('and', 'CC'), ('Querying', 'NNP'), ('e', 'VBP'), ('Catalog', 'NNP'), ('Communities', 'NNS')]
# [('Intelligent', 'NNP'), ('ad', 'NN'), ('resizing', 'NN')]
# [('A', 'DT'), ('Kb', 'NNP'), ('low', 'JJ'), ('power', 'NN'), ('T', 'NNP'), ('SRAM', 'NNP'), ('design', 'NN'), ('with', 'IN'), ('negative', 'JJ'), ('word', 'NN'), ('line', 'NN'), ('gate', 'NN'), ('drive', 'NN')]
# [('A', 'DT'), ('memory', 'NN'), ('efficient', 'NN'), ('continuous', 'JJ'), ('flow', 'NN'), ('FFT', 'NNP'), ('processor', 'NN'), ('for', 'IN'), ('Wimax', 'NNP'), ('application', 'NN')]
# [('Statistical', 'JJ'), ('Multiplexing', 'NNP'), ('Over', 'NNP'), ('DSL', 'NNP'), ('Networks', 'NNP')]
# [('A', 'DT'), ('Novel', 'NNP'), ('Quantitative', 'NNP'), ('Approach', 'NNP'), ('For', 'IN'), ('Measuring', 'NNP'), ('Network', 'NNP'), ('Security', 'NNP')]
# [('Comparative', 'JJ'), ('analysis', 'NN'), ('of', 'IN'), ('contrast', 'NN'), ('enhancement', 'NN'), ('algorithms', 'NN'), ('in', 'IN'), ('surveillance', 'NN'), ('imaging', 'NN')]
# [('Fast', 'NNP'), ('video', 'NN'), ('coding', 'VBG'), ('based', 'VBN'), ('on', 'IN'), ('Gaussian', 'JJ'), ('model', 'NN'), ('of', 'IN'), ('DCT', 'NNP'), ('coefficients', 'NNS')]
# [('Non', 'NNP'), ('linear', 'JJ'), ('aperture', 'NN'), ('for', 'IN'), ('stylized', 'JJ'), ('depth', 'NN'), ('of', 'IN'), ('field', 'NN')]
# [('MegaMind', 'NNP'), ('fire', 'NN'), ('smoke', 'NN'), ('and', 'CC'), ('data', 'NNS')]
# [('Simulation', 'NN'), ('of', 'IN'), ('object', 'NN'), ('and', 'CC'), ('human', 'JJ'), ('skin', 'NN'), ('formations', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('grasping', 'NN'), ('task', 'NN')]
# [('Wireless', 'NNP'), ('integrated', 'VBD'), ('circuit', 'NN'), ('for', 'IN'), ('the', 'DT'), ('acquisition', 'NN'), ('of', 'IN'), ('electrocorticogram', 'NN'), ('signals', 'NNS')]
# [('Privacy', 'NN'), ('nudges', 'NNS'), ('for', 'IN'), ('social', 'JJ'), ('media', 'NNS'), ('an', 'DT'), ('exploratory', 'NN'), ('Facebook', 'NNP'), ('study', 'NN')]
# [('Secure', 'NNP'), ('continuous', 'JJ'), ('aggregation', 'NN'), ('via', 'IN'), ('sampling', 'VBG'), ('based', 'VBN'), ('verification', 'NN'), ('in', 'IN'), ('wireless', 'NN'), ('sensor', 'NN'), ('networks', 'NNS')]
# [('On', 'IN'), ('rigorous', 'JJ'), ('integration', 'NN'), ('of', 'IN'), ('piece', 'NN'), ('wise', 'NN'), ('linear', 'VBP'), ('continuous', 'JJ'), ('systems', 'NNS')]
# [('Visibly', 'RB'), ('pushdown', 'JJ'), ('automata', 'NNS'), ('for', 'IN'), ('streaming', 'VBG'), ('XML', 'NN')]
# [('Video', 'NNP'), ('Multicast', 'NNP'), ('in', 'IN'), ('Large', 'NNP'), ('Local', 'NNP'), ('Area', 'NNP'), ('Networks', 'NNP')]
# [('Process', 'NNP'), ('insensitive', 'JJ'), ('modulated', 'VBD'), ('clock', 'NN'), ('voltage', 'NN'), ('comparator', 'NN')]
# [('An', 'DT'), ('Efficient', 'JJ'), ('Prony', 'NNP'), ('s', 'NN'), ('Method', 'NNP'), ('for', 'IN'), ('Time', 'NNP'), ('varying', 'VBG'), ('Power', 'NNP'), ('System', 'NNP'), ('Harmonic', 'NNP'), ('Estimation', 'NN')]
# [('A', 'DT'), ('novel', 'JJ'), ('CAVLC', 'NNP'), ('architecture', 'NN'), ('for', 'IN'), ('H', 'NNP'), ('Video', 'NNP'), ('encoding', 'VBG'), ('at', 'IN'), ('high', 'JJ'), ('bit', 'NN'), ('rate', 'NN')]
# [('Tongue', 'NNP'), ('visualization', 'NN'), ('for', 'IN'), ('specified', 'VBN'), ('speech', 'NN'), ('task', 'NN')]
# [('Smoother', 'NNP'), ('subsurface', 'NN'), ('scattering', 'VBG')]
# [('Core', 'NNP'), ('Stateless', 'NNP'), ('Guaranteed', 'NNP'), ('Rate', 'NNP'), ('Scheduling', 'NNP'), ('Algorithms', 'NNP')]
# [('A', 'DT'), ('Novel', 'NNP'), ('Ray', 'NNP'), ('space', 'NN'), ('based', 'VBN'), ('Color', 'NNP'), ('Correction', 'NNP'), ('Algorithm', 'NNP'), ('for', 'IN'), ('Multi', 'NNP'), ('view', 'NN'), ('Video', 'NNP')]
# [('Visualizing', 'VBG'), ('tags', 'NNS'), ('over', 'IN'), ('time', 'NN')]
# [('Driver', 'NNP'), ('s', 'PRP'), ('drowsiness', 'JJ'), ('estimation', 'NN'), ('by', 'IN'), ('combining', 'VBG'), ('EEG', 'NNP'), ('signal', 'JJ'), ('analysis', 'NN'), ('and', 'CC'), ('ICA', 'NNP'), ('based', 'VBN'), ('fuzzy', 'JJ'), ('neural', 'JJ'), ('networks', 'NNS')]
# [('Towards', 'IN'), ('a', 'DT'), ('programming', 'NN'), ('language', 'NN'), ('for', 'IN'), ('services', 'NNS'), ('computing', 'VBG')]
# [('Practical', 'JJ'), ('routing', 'VBG'), ('layer', 'JJ'), ('support', 'NN'), ('for', 'IN'), ('scalable', 'JJ'), ('multihoming', 'NN')]
# [('MRsionCase', 'NNP'), ('a', 'DT'), ('glasses', 'NNS'), ('free', 'JJ'), ('mixed', 'JJ'), ('reality', 'NN'), ('showcase', 'NN'), ('for', 'IN'), ('surrounding', 'VBG'), ('multiple', 'JJ'), ('viewers', 'NNS')]
# [('An', 'DT'), ('adaptive', 'JJ'), ('maximum', 'JJ'), ('power', 'NN'), ('point', 'NN'), ('tracker', 'NN'), ('for', 'IN'), ('maximising', 'VBG'), ('solar', 'JJ'), ('cell', 'NN'), ('efficiency', 'NN'), ('in', 'IN'), ('wireless', 'NN'), ('sensor', 'NN'), ('nodes', 'NNS')]
# [('An', 'DT'), ('All', 'NNP'), ('digital', 'JJ'), ('Skew', 'NNP'), ('adaptive', 'NN'), ('Clock', 'NNP'), ('Scheduling', 'NNP'), ('Algorithm', 'NNP'), ('for', 'IN'), ('Heterogeneous', 'NNP'), ('Multiprocessor', 'NNP'), ('Systems', 'NNPS'), ('on', 'IN'), ('Chips', 'NNP'), ('MPSoCs', 'NNP')]
# [('Interactive', 'JJ'), ('lighting', 'NN'), ('of', 'IN'), ('effects', 'NNS'), ('using', 'VBG'), ('point', 'NN'), ('clouds', 'NNS'), ('in', 'IN'), ('Bolt', 'NNP')]
# [('Keep', 'VB'), ('your', 'PRP$'), ('friends', 'NNS'), ('close', 'RB'), ('Incorporating', 'VBG'), ('trust', 'NN'), ('into', 'IN'), ('social', 'JJ'), ('network', 'NN'), ('based', 'VBN'), ('Sybil', 'NNP'), ('defenses', 'NNS')]
# [('A', 'DT'), ('Database', 'NNP'), ('Index', 'NNP'), ('to', 'TO'), ('Large', 'VB'), ('Biological', 'NNP'), ('Sequences', 'NNS')]
# [('Csurf', 'VB'), ('a', 'DT'), ('context', 'NN'), ('driven', 'VBN'), ('non', 'JJ'), ('visual', 'JJ'), ('web', 'NN'), ('browser', 'NN')]
# [('Rejecting', 'VBG'), ('the', 'DT'), ('attack', 'NN'), ('Source', 'NNP'), ('authentication', 'NN'), ('for', 'IN'), ('Wi', 'NNP'), ('Fi', 'NNP'), ('management', 'NN'), ('frames', 'NNS'), ('using', 'VBG'), ('CSI', 'NNP'), ('Information', 'NN')]
# [('Computer', 'NNP'), ('assisted', 'VBD'), ('animation', 'NN'), ('of', 'IN'), ('line', 'NN'), ('and', 'CC'), ('paint', 'NN'), ('in', 'IN'), ('Disney', 'NNP'), ('s', 'NN'), ('i', 'NN'), ('Paperman', 'NNP'), ('i', 'NN')]
# [('QoS', 'NNP'), ('Routing', 'VBG'), ('with', 'IN'), ('Performance', 'NNP'), ('Dependent', 'NNP'), ('Costs', 'NNS')]
# [('A', 'DT'), ('Concurrent', 'NNP'), ('Database', 'NNP'), ('Manipulation', 'NNP'), ('Problem', 'NNP'), ('Binary', 'NNP'), ('Search', 'NNP'), ('Trees', 'NNP'), ('Abstract', 'NNP')]
# [('A', 'DT'), ('reconfigurable', 'JJ'), ('MAC', 'NNP'), ('architecture', 'NN'), ('implemented', 'VBN'), ('with', 'IN'), ('mixed', 'JJ'), ('Vt', 'NNP'), ('standard', 'NN'), ('cell', 'NN'), ('library', 'NN')]
# [('MEMS', 'NNP'), ('automotive', 'JJ'), ('collision', 'NN'), ('avoidence', 'NN'), ('radar', 'NN'), ('beamformer', 'NN')]
# [('Execution', 'NN'), ('time', 'NN'), ('comparison', 'NN'), ('of', 'IN'), ('lifting', 'VBG'), ('based', 'VBN'), ('D', 'NNP'), ('wavelet', 'NN'), ('transforms', 'NNS'), ('implementations', 'NNS'), ('on', 'IN'), ('a', 'DT'), ('VLIW', 'NNP'), ('DSP', 'NNP')]
# [('SPARQL', 'NNP'), ('basic', 'JJ'), ('graph', 'NN'), ('pattern', 'NN'), ('optimization', 'NN'), ('using', 'VBG'), ('selectivity', 'NN'), ('estimation', 'NN')]
# [('A', 'DT'), ('wide', 'JJ'), ('tuning', 'NN'), ('quasi', 'NN'), ('type', 'NN'), ('I', 'PRP'), ('PLL', 'VBP'), ('with', 'IN'), ('voltage', 'NN'), ('mode', 'NN'), ('frequency', 'NN'), ('acquisition', 'NN'), ('aid', 'NN')]
# [('Animating', 'VBG'), ('art', 'JJ'), ('history', 'NN'), ('building', 'VBG'), ('a', 'DT'), ('bridge', 'NN'), ('between', 'IN'), ('disciplines', 'NNS')]
# [('V', 'NNP'), ('buffer', 'VBP'), ('visible', 'JJ'), ('volume', 'NN'), ('rendering', 'VBG')]
# [('The', 'DT'), ('Magic', 'NNP'), ('of', 'IN'), ('Duplicates', 'NNP'), ('and', 'CC'), ('Aggregates', 'NNS')]
# [('Personalized', 'VBN'), ('pocket', 'NN'), ('directories', 'NNS'), ('for', 'IN'), ('mobile', 'JJ'), ('devices', 'NNS')]
# [('Record', 'NN'), ('Subtype', 'NN'), ('Facilities', 'NNS'), ('in', 'IN'), ('Database', 'NNP'), ('Systems', 'NNPS')]
# [('Illumination', 'NN'), ('in', 'IN'), ('diverse', 'JJ'), ('codimensions', 'NNS')]
# [('Joint', 'NNP'), ('optimal', 'JJ'), ('scheduling', 'NN'), ('and', 'CC'), ('routing', 'NN'), ('for', 'IN'), ('maximum', 'JJ'), ('network', 'NN'), ('throughput', 'NN')]
# [('A', 'DT'), ('CMOS', 'NNP'), ('high', 'JJ'), ('IIP', 'NNP'), ('mixer', 'NN'), ('for', 'IN'), ('multi', 'JJ'), ('standard', 'NN'), ('receivers', 'NNS')]
# [('Partitioning', 'VBG'), ('and', 'CC'), ('ordering', 'VBG'), ('large', 'JJ'), ('radiosity', 'NN'), ('computations', 'NNS')]
# [('Generalized', 'VBN'), ('arbitrary', 'JJ'), ('resizing', 'NN'), ('for', 'IN'), ('video', 'NN'), ('transcoding', 'NN')]
# [('On', 'IN'), ('the', 'DT'), ('impact', 'NN'), ('of', 'IN'), ('global', 'JJ'), ('information', 'NN'), ('on', 'IN'), ('diffusion', 'NN'), ('of', 'IN'), ('innovations', 'NNS'), ('over', 'IN'), ('social', 'JJ'), ('networks', 'NNS')]
# [('Analysis', 'NN'), ('for', 'IN'), ('Signal', 'NNP'), ('and', 'CC'), ('Power', 'NNP'), ('Integrity', 'NNP'), ('Using', 'VBG'), ('the', 'DT'), ('Multilayered', 'NNP'), ('Finite', 'NNP'), ('Difference', 'NNP'), ('Method', 'NNP')]
# [('Probability', 'NNP'), ('Distribution', 'NNP'), ('of', 'IN'), ('Blackouts', 'NNP'), ('in', 'IN'), ('Complex', 'NNP'), ('Power', 'NNP'), ('Networks', 'NNP')]
# [('Write', 'NNP'), ('Optimized', 'NNP'), ('B', 'NNP'), ('Trees', 'NNP')]
# [('Cross', 'NNP'), ('Regulation', 'NNP'), ('Suppression', 'NNP'), ('control', 'NN'), ('scheme', 'NN'), ('for', 'IN'), ('CCM', 'NNP'), ('Single', 'NNP'), ('Inductor', 'NNP'), ('Dual', 'NNP'), ('Output', 'NNP'), ('buck', 'VBD'), ('converter', 'NN'), ('with', 'IN'), ('ordered', 'JJ'), ('power', 'NN'), ('distributive', 'NN'), ('control', 'NN')]
# [('A', 'DT'), ('New', 'NNP'), ('Gbps', 'NNP'), ('Traffic', 'NNP'), ('Management', 'NNP'), ('algorithm', 'NN'), ('for', 'IN'), ('High', 'NNP'), ('speed', 'NN'), ('Networks', 'NNS')]
# [('Bifurcations', 'NNS'), ('and', 'CC'), ('chaos', 'NN'), ('in', 'IN'), ('electrostatic', 'JJ'), ('vibration', 'NN'), ('energy', 'NN'), ('harvesters', 'NNS')]
# [('A', 'DT'), ('proposal', 'NN'), ('of', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('blind', 'NN'), ('equalizer', 'NN'), ('using', 'VBG'), ('output', 'NN'), ('signals', 'NNS'), ('of', 'IN'), ('decision', 'NN'), ('device', 'NN')]
# [('Distributed', 'VBN'), ('video', 'NN'), ('coding', 'VBG'), ('using', 'VBG'), ('wavelet', 'NN')]
# [('Using', 'VBG'), ('eye', 'NN'), ('tracking', 'VBG'), ('to', 'TO'), ('analyze', 'VB'), ('stereoscopic', 'NN'), ('filmmaking', 'NN')]
# [('Porqpine', 'VB'), ('A', 'NNP'), ('Distributed', 'NNP'), ('and', 'CC'), ('Collaborative', 'NNP'), ('Search', 'NNP'), ('Engine', 'NNP')]
# [('A', 'DT'), ('time', 'NN'), ('domain', 'NN'), ('gradient', 'JJ'), ('detection', 'NN'), ('architecture', 'NN'), ('for', 'IN'), ('VLSI', 'NNP'), ('analog', 'NN'), ('motion', 'NN'), ('sensors', 'NNS')]
# [('High', 'JJ'), ('dynamic', 'JJ'), ('range', 'NN'), ('imaging', 'VBG'), ('using', 'VBG'), ('coded', 'VBN'), ('electronic', 'JJ'), ('shutter', 'NN')]
# [('Automated', 'NNP'), ('semantic', 'JJ'), ('web', 'NN'), ('services', 'NNS'), ('orchestration', 'NN'), ('via', 'IN'), ('concept', 'NN'), ('covering', 'VBG')]
# [('Incremental', 'JJ'), ('Maintenance', 'NNP'), ('for', 'IN'), ('Non', 'NNP'), ('Distributive', 'NNP'), ('Aggregate', 'NNP'), ('Functions', 'NNS')]
# [('A', 'DT'), ('simple', 'JJ'), ('modeling', 'NN'), ('of', 'IN'), ('the', 'DT'), ('early', 'JJ'), ('voltage', 'NN'), ('of', 'IN'), ('MOSFETs', 'NNP'), ('in', 'IN'), ('weak', 'JJ'), ('and', 'CC'), ('moderate', 'JJ'), ('inversion', 'NN')]
# [('Towards', 'IN'), ('a', 'DT'), ('Common', 'NNP'), ('Infrastructure', 'NN'), ('to', 'TO'), ('Support', 'NNP'), ('Heterogeneous', 'NNP'), ('Learning', 'NNP'), ('Experiences', 'NNS')]
# [('Plurality', 'NN'), ('a', 'DT'), ('context', 'NN'), ('aware', 'JJ'), ('personalized', 'VBN'), ('tagging', 'NN'), ('system', 'NN')]
# [('Realistic', 'JJ'), ('and', 'CC'), ('Efficient', 'JJ'), ('Multi', 'NNP'), ('Channel', 'NNP'), ('Communications', 'NNPS'), ('in', 'IN'), ('Wireless', 'NNP'), ('Sensor', 'NNP'), ('Networks', 'NNP')]
# [('Localization', 'NN'), ('in', 'IN'), ('D', 'NNP'), ('surface', 'NN'), ('sensor', 'NN'), ('networks', 'NNS'), ('Challenges', 'NNP'), ('and', 'CC'), ('solutions', 'NNS')]
# [('SAT', 'NNP'), ('based', 'VBN'), ('ATPG', 'NNP'), ('for', 'IN'), ('Path', 'NNP'), ('Delay', 'NNP'), ('Faults', 'NNP'), ('in', 'IN'), ('Sequential', 'NNP'), ('Circuits', 'NNP')]
# [('Spectrally', 'RB'), ('optimal', 'JJ'), ('sampling', 'VBG'), ('for', 'IN'), ('distribution', 'NN'), ('ray', 'NN'), ('tracing', 'VBG')]
# [('Cloudy', 'VB'), ('A', 'DT'), ('Modular', 'JJ'), ('Cloud', 'NNP'), ('Storage', 'NN'), ('System', 'NN')]
# [('Design', 'NN'), ('of', 'IN'), ('OOK', 'NNP'), ('system', 'NN'), ('for', 'IN'), ('wireless', 'NN'), ('capsule', 'NN'), ('endoscopy', 'NN')]
# [('Gesture', 'NNP'), ('world', 'NN'), ('technology', 'NN'), ('D', 'NNP'), ('hand', 'NN'), ('pose', 'NN'), ('estimation', 'NN'), ('system', 'NN'), ('for', 'IN'), ('unspecified', 'JJ'), ('users', 'NNS'), ('using', 'VBG'), ('a', 'DT'), ('compact', 'JJ'), ('high', 'JJ'), ('speed', 'NN'), ('camera', 'NN')]
# [('Generalizations', 'NNS'), ('of', 'IN'), ('Oja', 'NNP'), ('s', 'NN'), ('Learning', 'NNP'), ('Rule', 'NNP'), ('to', 'TO'), ('Non', 'NNP'), ('Symmetric', 'NNP'), ('Matrices', 'NNS')]
# [('Content', 'NNP'), ('aware', 'JJ'), ('caching', 'NN'), ('and', 'CC'), ('traffic', 'NN'), ('management', 'NN'), ('in', 'IN'), ('content', 'JJ'), ('distribution', 'NN'), ('networks', 'NNS')]
# [('FALCON', 'NNP'), ('Feedback', 'NNP'), ('Adaptive', 'NNP'), ('Loop', 'NNP'), ('for', 'IN'), ('Content', 'NNP'), ('Based', 'VBD'), ('Retrieval', 'NNP')]
# [('Image', 'NN'), ('based', 'VBN'), ('flow', 'JJ'), ('visualization', 'NN')]
# [('Energy', 'NNP'), ('efficient', 'JJ'), ('collaborative', 'JJ'), ('sensing', 'NN'), ('with', 'IN'), ('mobile', 'JJ'), ('phones', 'NNS')]
# [('What', 'WP'), ('is', 'VBZ'), ('the', 'DT'), ('importance', 'NN'), ('of', 'IN'), ('selecting', 'VBG'), ('features', 'NNS'), ('for', 'IN'), ('non', 'JJ'), ('technical', 'JJ'), ('losses', 'NNS'), ('identification', 'NN')]
# [('Predictions', 'NNS'), ('and', 'CC'), ('Challenges', 'NNP'), ('for', 'IN'), ('Database', 'NNP'), ('Systems', 'NNPS'), ('in', 'IN'), ('the', 'DT'), ('Year', 'NN')]
# [('Coordination', 'NN'), ('in', 'IN'), ('network', 'NN'), ('security', 'NN'), ('games', 'NNS')]
# [('Enabling', 'VBG'), ('entity', 'NN'), ('based', 'VBN'), ('aggregators', 'NNS'), ('for', 'IN'), ('web', 'NN'), ('data', 'NNS')]
# [('Energy', 'NNP'), ('function', 'NN'), ('based', 'VBN'), ('neural', 'JJ'), ('networks', 'NNS'), ('UPFC', 'NNP'), ('for', 'IN'), ('transient', 'JJ'), ('stability', 'NN'), ('enhancement', 'NN'), ('of', 'IN'), ('network', 'NN'), ('preserving', 'VBG'), ('power', 'NN'), ('systems', 'NNS')]
# [('Real', 'JJ'), ('time', 'NN'), ('simulation', 'NN'), ('in', 'IN'), ('the', 'DT'), ('real', 'JJ'), ('world', 'NN'), ('panel', 'NN'), ('session', 'NN')]
# [('Social', 'NNP'), ('search', 'NN'), ('and', 'CC'), ('discovery', 'NN'), ('using', 'VBG'), ('a', 'DT'), ('unified', 'JJ'), ('approach', 'NN')]
# [('Run', 'NNP'), ('Time', 'NNP'), ('Programming', 'NNP'), ('of', 'IN'), ('Analog', 'NNP'), ('Circuits', 'NNP'), ('Using', 'NNP'), ('Floating', 'NNP'), ('Gate', 'NNP'), ('Transistors', 'NNS')]
# [('User', 'NNP'), ('Interaction', 'NNP'), ('Experience', 'NNP'), ('for', 'IN'), ('Semantic', 'NNP'), ('Web', 'NNP'), ('Information', 'NN')]
# [('A', 'DT'), ('versatile', 'NN'), ('I', 'PRP'), ('O', 'VBP'), ('with', 'IN'), ('robust', 'JJ'), ('impedance', 'NN'), ('calibration', 'NN'), ('for', 'IN'), ('various', 'JJ'), ('memory', 'NN'), ('interfaces', 'NNS')]
# [('The', 'DT'), ('Integrated', 'NNP'), ('Microbial', 'NNP'), ('Genomes', 'NNP'), ('IMG', 'NNP'), ('System', 'NNP'), ('A', 'NNP'), ('Case', 'NNP'), ('Study', 'NNP'), ('in', 'IN'), ('Biological', 'NNP'), ('Data', 'NNP'), ('Management', 'NNP')]
# [('The', 'DT'), ('Theory', 'NNP'), ('of', 'IN'), ('Probabilistic', 'NNP'), ('Databases', 'NNP')]
# [('Design', 'NN'), ('and', 'CC'), ('optimization', 'NN'), ('of', 'IN'), ('two', 'CD'), ('motion', 'NN'), ('detection', 'NN'), ('circuits', 'NNS'), ('for', 'IN'), ('video', 'NN'), ('monitoring', 'NN'), ('system', 'NN')]
# [('Realistic', 'JJ'), ('and', 'CC'), ('interactive', 'JJ'), ('image', 'NN'), ('based', 'VBN'), ('rendering', 'NN'), ('of', 'IN'), ('ancient', 'JJ'), ('chinese', 'JJ'), ('artifacts', 'NNS'), ('using', 'VBG'), ('a', 'DT'), ('multiple', 'JJ'), ('camera', 'NN'), ('array', 'NN')]
# [('Recovery', 'NN'), ('and', 'CC'), ('Coherency', 'NNP'), ('Control', 'NNP'), ('Protocols', 'NNP'), ('for', 'IN'), ('Fast', 'NNP'), ('Intersystem', 'NNP'), ('Page', 'NNP'), ('Transfer', 'NNP'), ('and', 'CC'), ('Fine', 'NNP'), ('Granularity', 'NNP'), ('Locking', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('Shared', 'NNP'), ('Disks', 'NNP'), ('Transaction', 'NNP'), ('Environment', 'NNP')]
# [('The', 'DT'), ('V', 'NNP'), ('Diagram', 'NNP'), ('a', 'DT'), ('query', 'NN'), ('dependent', 'JJ'), ('approach', 'NN'), ('to', 'TO'), ('moving', 'VBG'), ('KNN', 'NNP'), ('queries', 'NNS')]
# [('Digital', 'NNP'), ('RF', 'NNP'), ('Processing', 'NNP'), ('Techniques', 'NNP'), ('for', 'IN'), ('Device', 'NNP'), ('Mismatch', 'NNP'), ('Tolerant', 'NNP'), ('Transmitters', 'NNP'), ('in', 'IN'), ('Nanometer', 'NNP'), ('Scale', 'NNP'), ('CMOS', 'NNP')]
# [('Cooperative', 'JJ'), ('Network', 'NNP'), ('Coding', 'NNP'), ('Aware', 'NNP'), ('Routing', 'NNP'), ('for', 'IN'), ('Multi', 'NNP'), ('Rate', 'NNP'), ('Wireless', 'NNP'), ('Networks', 'NNP')]
# [('A', 'DT'), ('logical', 'JJ'), ('framework', 'NN'), ('for', 'IN'), ('temporal', 'JJ'), ('deductive', 'JJ'), ('databases', 'NNS')]
# [('Manage', 'NN'), ('and', 'CC'), ('Query', 'NNP'), ('Generic', 'NNP'), ('Moving', 'NNP'), ('Objects', 'NNP'), ('in', 'IN'), ('SECONDO', 'NNP')]
# [('How', 'WRB'), ('to', 'TO'), ('reach', 'VB'), ('coding', 'VBG'), ('efficiency', 'NN'), ('in', 'IN'), ('multilevel', 'JJ'), ('burst', 'NN'), ('mode', 'NN'), ('RF', 'NNP'), ('transmitters', 'NNS')]
# [('Fast', 'NNP'), ('Reconfiguration', 'NNP'), ('Experiments', 'NNP'), ('of', 'IN'), ('an', 'DT'), ('Optically', 'NNP'), ('Differential', 'NNP'), ('Reconfigurable', 'NNP'), ('Gate', 'NNP'), ('Array', 'NNP'), ('with', 'IN'), ('Nine', 'NNP'), ('Configuration', 'NNP'), ('Contexts', 'NNP')]
# [('Towards', 'IN'), ('a', 'DT'), ('comprehensive', 'JJ'), ('and', 'CC'), ('systematic', 'JJ'), ('classification', 'NN'), ('of', 'IN'), ('hardware', 'NN'), ('Trojans', 'NNS')]
# [('An', 'DT'), ('inductively', 'RB'), ('tuned', 'JJ'), ('CMOS', 'NNP'), ('astable', 'JJ'), ('multivibrator', 'NN')]
# [('dRig', 'NN'), ('an', 'DT'), ('artist', 'NN'), ('friendly', 'JJ'), ('object', 'NN'), ('oriented', 'VBN'), ('approach', 'NN'), ('to', 'TO'), ('rig', 'VB'), ('building', 'NN')]
# [('The', 'DT'), ('web', 'NN'), ('beyond', 'IN'), ('popularity', 'NN'), ('a', 'DT'), ('really', 'RB'), ('simple', 'JJ'), ('system', 'NN'), ('for', 'IN'), ('web', 'JJ'), ('scale', 'NN'), ('RSS', 'NNP')]
# [('A', 'DT'), ('CMOS', 'NNP'), ('linear', 'JJ'), ('voltage', 'NN'), ('current', 'JJ'), ('dual', 'JJ'), ('mode', 'NN'), ('imager', 'NN')]
# [('Model', 'NNP'), ('and', 'CC'), ('Architecture', 'NNP'), ('of', 'IN'), ('a', 'DT'), ('Timing', 'NNP'), ('Service', 'NNP'), ('for', 'IN'), ('Adaptive', 'NNP'), ('Policy', 'NNP'), ('Based', 'VBD'), ('Management', 'NNP'), ('Systems', 'NNPS')]
# [('Frequency', 'NNP'), ('Response', 'NNP'), ('Masking', 'NNP'), ('based', 'VBN'), ('Reconfigurable', 'JJ'), ('Channel', 'NNP'), ('Filters', 'NNP'), ('for', 'IN'), ('Software', 'NNP'), ('Radio', 'NNP'), ('Receivers', 'NNP')]
# [('Partitioning', 'VBG'), ('and', 'CC'), ('synthesis', 'NN'), ('for', 'IN'), ('hybrid', 'JJ'), ('architecture', 'NN'), ('simulators', 'NNS')]
# [('A', 'DT'), ('parallel', 'JJ'), ('search', 'NN'), ('algorithm', 'NN'), ('for', 'IN'), ('CLNS', 'NNP'), ('addition', 'NN'), ('optimization', 'NN')]
# [('Instrumenting', 'VBG'), ('a', 'DT'), ('logic', 'JJ'), ('programming', 'NN'), ('language', 'NN'), ('to', 'TO'), ('gather', 'VB'), ('provenance', 'NN'), ('from', 'IN'), ('an', 'DT'), ('information', 'NN'), ('extraction', 'NN'), ('application', 'NN')]
# [('SMOOTH', 'VB'), ('A', 'NNP'), ('Distributed', 'NNP'), ('Multimedia', 'NNP'), ('Database', 'NNP'), ('System', 'NNP')]
# [('Loop', 'NNP'), ('mitigation', 'NN'), ('in', 'IN'), ('bloom', 'NN'), ('filter', 'NN'), ('based', 'VBN'), ('multicast', 'PDT'), ('A', 'DT'), ('destination', 'NN'), ('oriented', 'VBN'), ('approach', 'NN')]
# [('Influence', 'NN'), ('of', 'IN'), ('external', 'JJ'), ('input', 'NN'), ('on', 'IN'), ('Oscillatory', 'NNP'), ('Cellular', 'NNP'), ('Nonlinear', 'NNP'), ('Networks', 'NNP'), ('dynamics', 'NNS')]
# [('Efficient', 'JJ'), ('design', 'NN'), ('of', 'IN'), ('sparse', 'NN'), ('FIR', 'NNP'), ('filters', 'NNS'), ('in', 'IN'), ('WLS', 'NNP'), ('sense', 'NN')]
# [('A', 'DT'), ('metro', 'NN'), ('map', 'NN'), ('metaphor', 'NN'), ('for', 'IN'), ('guided', 'JJ'), ('tours', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('Web', 'NNP'), ('the', 'DT'), ('Webvise', 'NNP'), ('guided', 'VBD'), ('tour', 'NN'), ('system', 'NN')]
# [('GPX', 'NNP'), ('Interactive', 'NNP'), ('Mining', 'NNP'), ('of', 'IN'), ('Gene', 'NNP'), ('Expression', 'NNP'), ('Data', 'NNP')]
# [('Video', 'NNP'), ('sharing', 'VBG'), ('propagation', 'NN'), ('in', 'IN'), ('social', 'JJ'), ('networks', 'NNS'), ('Measurement', 'NNP'), ('modeling', 'NN'), ('and', 'CC'), ('analysis', 'NN')]
# [('Variable', 'JJ'), ('fractional', 'JJ'), ('delay', 'NN'), ('FIR', 'NNP'), ('filters', 'NNS'), ('with', 'IN'), ('sparse', 'JJ'), ('coefficients', 'NNS')]
# [('Hexahedral', 'NNP'), ('Mesh', 'NNP'), ('Re', 'NNP'), ('parameterization', 'NN'), ('from', 'IN'), ('Aligned', 'JJ'), ('Base', 'NNP'), ('Domains', 'NNP')]
# [('The', 'DT'), ('largest', 'JJS'), ('scholarly', 'RB'), ('semantic', 'JJ'), ('network', 'NN'), ('ever', 'RB')]
# [('iPvlc', 'JJ'), ('pixel', 'NN'), ('level', 'NN'), ('visible', 'JJ'), ('light', 'JJ'), ('communication', 'NN'), ('for', 'IN'), ('smart', 'JJ'), ('mobile', 'JJ'), ('devices', 'NNS')]
# [('New', 'NNP'), ('FPN', 'NNP'), ('correction', 'NN'), ('method', 'NN'), ('for', 'IN'), ('PD', 'NNP'), ('storage', 'NN'), ('dual', 'JJ'), ('capture', 'NN'), ('CMOS', 'NNP'), ('image', 'NN'), ('sensor', 'NN'), ('using', 'VBG'), ('a', 'DT'), ('nonfully', 'RB'), ('depleted', 'VBN'), ('pinned', 'JJ'), ('photodiode', 'NN')]
# [('Dissemination', 'NN'), ('of', 'IN'), ('Models', 'NNP'), ('over', 'IN'), ('Time', 'NNP'), ('Varying', 'NNP'), ('Data', 'NNP')]
# [('Application', 'NN'), ('of', 'IN'), ('two', 'CD'), ('layered', 'JJ'), ('tabu', 'NNS'), ('search', 'NN'), ('to', 'TO'), ('optimal', 'JJ'), ('allocation', 'NN'), ('of', 'IN'), ('UPFC', 'NNP'), ('for', 'IN'), ('maximizing', 'VBG'), ('transmission', 'NN'), ('capability', 'NN')]
# [('Enhancing', 'VBG'), ('Traffic', 'NNP'), ('Sampling', 'NNP'), ('scope', 'NN'), ('and', 'CC'), ('efficiency', 'NN')]
# [('Low', 'JJ'), ('phase', 'NN'), ('noise', 'NN'), ('on', 'IN'), ('chip', 'NN'), ('oscillator', 'NN'), ('for', 'IN'), ('implantable', 'JJ'), ('biomedical', 'JJ'), ('applications', 'NNS')]
# [('CodePipe', 'NNP'), ('An', 'DT'), ('opportunistic', 'JJ'), ('feeding', 'NN'), ('and', 'CC'), ('routing', 'VBG'), ('protocol', 'NN'), ('for', 'IN'), ('reliable', 'JJ'), ('multicast', 'NN'), ('with', 'IN'), ('pipelined', 'JJ'), ('network', 'NN'), ('coding', 'VBG')]
# [('On', 'IN'), ('Hybrid', 'NNP'), ('Collision', 'NNP'), ('Control', 'NNP'), ('for', 'IN'), ('IEEE', 'NNP'), ('Ad', 'NNP'), ('Hoc', 'NNP'), ('Networks', 'NNP')]
# [('Challenges', 'NNS'), ('and', 'CC'), ('recent', 'JJ'), ('advances', 'NNS'), ('in', 'IN'), ('IR', 'NNP'), ('UWB', 'NNP'), ('system', 'NN'), ('design', 'NN')]
# [('Shape', 'NNP'), ('transformation', 'NN'), ('for', 'IN'), ('polyhedral', 'JJ'), ('objects', 'NNS')]
# [('A', 'DT'), ('flexible', 'JJ'), ('generative', 'JJ'), ('model', 'NN'), ('for', 'IN'), ('preference', 'NN'), ('aggregation', 'NN')]
# [('Characterizing', 'VBG'), ('geospatial', 'JJ'), ('dynamics', 'NNS'), ('of', 'IN'), ('application', 'NN'), ('usage', 'NN'), ('in', 'IN'), ('a', 'DT'), ('G', 'NNP'), ('cellular', 'JJ'), ('data', 'NNS'), ('network', 'NN')]
# [('Noise', 'NNP'), ('Reduction', 'NNP'), ('System', 'NNP'), ('Based', 'VBD'), ('on', 'IN'), ('LPEF', 'NNP'), ('and', 'CC'), ('System', 'NNP'), ('Identification', 'NNP'), ('with', 'IN'), ('Variable', 'NNP'), ('Step', 'NNP'), ('Size', 'NNP')]
# [('A', 'DT'), ('full', 'JJ'), ('custom', 'NN'), ('design', 'NN'), ('of', 'IN'), ('AES', 'NNP'), ('SubByte', 'NNP'), ('module', 'NN'), ('with', 'IN'), ('signal', 'JJ'), ('independent', 'JJ'), ('power', 'NN'), ('consumption', 'NN')]
# [('A', 'DT'), ('time', 'NN'), ('efficient', 'JJ'), ('information', 'NN'), ('collection', 'NN'), ('protocol', 'NN'), ('for', 'IN'), ('large', 'JJ'), ('scale', 'JJ'), ('RFID', 'NNP'), ('systems', 'NNS')]
# [('MITE', 'NNP'), ('Product', 'NNP'), ('of', 'IN'), ('Power', 'NNP'), ('Law', 'NNP'), ('Networks', 'NNS')]
# [('Filtering', 'VBG'), ('with', 'IN'), ('Approximate', 'NNP'), ('Predicates', 'NNS')]
# [('Estimating', 'VBG'), ('the', 'DT'), ('prevalence', 'NN'), ('of', 'IN'), ('deception', 'NN'), ('in', 'IN'), ('online', 'JJ'), ('review', 'NN'), ('communities', 'NNS')]
# [('Bounding', 'VBG'), ('the', 'DT'), ('power', 'NN'), ('rate', 'NN'), ('function', 'NN'), ('of', 'IN'), ('wireless', 'NN'), ('ad', 'NN'), ('hoc', 'NN'), ('networks', 'NNS')]
# [('Data', 'NNP'), ('Broadcasting', 'NNP'), ('and', 'CC'), ('Seamless', 'NNP'), ('Channel', 'NNP'), ('Transition', 'NNP'), ('for', 'IN'), ('Highly', 'NNP'), ('Demanded', 'NNP'), ('Videos', 'NNP')]
# [('MMSE', 'NNP'), ('based', 'VBN'), ('design', 'NN'), ('of', 'IN'), ('scaled', 'JJ'), ('and', 'CC'), ('offset', 'VB'), ('BP', 'NNP'), ('based', 'VBN'), ('decoding', 'VBG'), ('algorithms', 'NN'), ('on', 'IN'), ('the', 'DT'), ('fast', 'JJ'), ('Rayleigh', 'NNP'), ('fading', 'NN'), ('channel', 'NN')]
# [('News', 'NN'), ('in', 'IN'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('the', 'DT'), ('web', 'NN')]
# [('Polygon', 'NNP'), ('assisted', 'VBD'), ('JPEG', 'NNP'), ('and', 'CC'), ('MPEG', 'NNP'), ('compression', 'NN'), ('of', 'IN'), ('synthetic', 'JJ'), ('images', 'NNS')]
# [('Unsupervised', 'VBN'), ('query', 'NN'), ('segmentation', 'NN'), ('using', 'VBG'), ('click', 'JJ'), ('data', 'NNS'), ('preliminary', 'JJ'), ('results', 'NNS')]
# [('Modeling', 'VBG'), ('and', 'CC'), ('understanding', 'VBG'), ('TCP', 'NNP'), ('incast', 'NN'), ('in', 'IN'), ('data', 'NNS'), ('center', 'NN'), ('networks', 'NNS')]
# [('A', 'DT'), ('Low', 'JJ'), ('Jitter', 'NNP'), ('CMOS', 'NNP'), ('PLL', 'NNP'), ('Clock', 'NNP'), ('Synthesizer', 'NNP'), ('with', 'IN'), ('MHz', 'NNP'), ('Locking', 'NNP'), ('Range', 'NNP')]
# [('BSSRDF', 'NNP'), ('importance', 'NN'), ('sampling', 'VBG')]
# [('Extraction', 'NN'), ('of', 'IN'), ('robust', 'JJ'), ('visual', 'JJ'), ('phrases', 'NNS'), ('using', 'VBG'), ('graph', 'NN'), ('mining', 'NN'), ('for', 'IN'), ('image', 'NN'), ('retrieval', 'NN')]
# [('A', 'DT'), ('Singlehop', 'NNP'), ('Collaborative', 'NNP'), ('Feedback', 'NNP'), ('Primitive', 'NNP'), ('for', 'IN'), ('Wireless', 'NNP'), ('Sensor', 'NNP'), ('Networks', 'NNP')]
# [('Highly', 'NNP'), ('parallel', 'JJ'), ('image', 'NN'), ('coding', 'VBG'), ('for', 'IN'), ('many', 'JJ'), ('cores', 'NNS')]
# [('Protocol', 'NNP'), ('level', 'NN'), ('performance', 'NN'), ('analysis', 'NN'), ('for', 'IN'), ('anti', 'JJ'), ('collision', 'NN'), ('protocols', 'NNS'), ('in', 'IN'), ('RFID', 'NNP'), ('systems', 'NNS')]
# [('Distance', 'NNP'), ('Indexing', 'NNP'), ('on', 'IN'), ('Road', 'NNP'), ('Networks', 'NNP')]
# [('Reconfigurable', 'JJ'), ('cell', 'NN'), ('array', 'NN'), ('for', 'IN'), ('concurrent', 'JJ'), ('support', 'NN'), ('of', 'IN'), ('multiple', 'JJ'), ('radio', 'NN'), ('standards', 'NNS'), ('by', 'IN'), ('flexible', 'JJ'), ('mapping', 'NN')]
# [('Creating', 'VBG'), ('Competitive', 'JJ'), ('Products', 'NNS')]
# [('Sensory', 'NNP'), ('design', 'NN'), ('for', 'IN'), ('virtual', 'JJ'), ('environments', 'NNS')]
# [('Optimal', 'NNP'), ('Bandwidth', 'NNP'), ('Reservation', 'NNP'), ('in', 'IN'), ('Hose', 'NNP'), ('Model', 'NNP'), ('VPNs', 'NNP'), ('with', 'IN'), ('Multi', 'NNP'), ('Path', 'NNP'), ('Routing', 'NNP')]
# [('Optimal', 'JJ'), ('Waveband', 'NNP'), ('Switching', 'NNP'), ('in', 'IN'), ('Optical', 'NNP'), ('Ring', 'NNP'), ('Networks', 'NNP')]
# [('Exploiting', 'VBG'), ('channel', 'NNS'), ('memory', 'NN'), ('for', 'IN'), ('joint', 'JJ'), ('estimation', 'NN'), ('and', 'CC'), ('scheduling', 'NN'), ('in', 'IN'), ('downlink', 'NN'), ('networks', 'NNS')]
# [('Multiuser', 'NNP'), ('detection', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('Grover', 'NNP'), ('s', 'NN'), ('algorithm', 'NN')]
# [('Impact', 'NN'), ('of', 'IN'), ('File', 'NNP'), ('Arrivals', 'NNP'), ('and', 'CC'), ('Departures', 'NNP'), ('on', 'IN'), ('Buffer', 'NNP'), ('Sizing', 'NNP'), ('in', 'IN'), ('Core', 'NNP'), ('Routers', 'NNS')]
# [('Towards', 'IN'), ('a', 'DT'), ('theory', 'NN'), ('model', 'NN'), ('for', 'IN'), ('product', 'NN'), ('search', 'NN')]
# [('Fourier', 'NNP'), ('series', 'NN'), ('analysis', 'NN'), ('of', 'IN'), ('the', 'DT'), ('nonlinearities', 'NNS'), ('in', 'IN'), ('analog', 'NN'), ('closed', 'VBD'), ('loop', 'JJ'), ('PWM', 'NNP'), ('class', 'NN'), ('D', 'NNP'), ('amplifiers', 'NNS')]
# [('Data', 'NNP'), ('fusion', 'NN'), ('Resolving', 'NNP'), ('Data', 'NNP'), ('Conflicts', 'NNP'), ('for', 'IN'), ('Integration', 'NNP')]
# [('Argus', 'JJ'), ('End', 'NN'), ('to', 'TO'), ('end', 'VB'), ('service', 'NN'), ('anomaly', 'JJ'), ('detection', 'NN'), ('and', 'CC'), ('localization', 'NN'), ('from', 'IN'), ('an', 'DT'), ('ISP', 'NNP'), ('s', 'NN'), ('point', 'NN'), ('of', 'IN'), ('view', 'NN')]
# [('Signal', 'NNP'), ('modulus', 'CC'), ('design', 'NN'), ('for', 'IN'), ('blind', 'NN'), ('source', 'NN'), ('separation', 'NN'), ('via', 'IN'), ('algebraic', 'JJ'), ('known', 'VBN'), ('modulus', 'JJ'), ('algorithm', 'NN'), ('A', 'DT'), ('perturbation', 'NN'), ('perspective', 'NN')]
# [('Small', 'JJ'), ('World', 'NNP'), ('File', 'NNP'), ('Sharing', 'VBG'), ('Communities', 'NNS')]
# [('Local', 'JJ'), ('Disk', 'NNP'), ('Caching', 'NNP'), ('for', 'IN'), ('Client', 'NNP'), ('Server', 'NNP'), ('Database', 'NNP'), ('Systems', 'NNP')]
# [('A', 'DT'), ('novel', 'JJ'), ('polynomial', 'JJ'), ('selection', 'NN'), ('scheme', 'NN'), ('for', 'IN'), ('low', 'JJ'), ('complexity', 'NN'), ('chase', 'NN'), ('algebraic', 'JJ'), ('soft', 'JJ'), ('decision', 'NN'), ('reed', 'NN'), ('solomon', 'NN'), ('decoding', 'VBG')]
# [('Autonomous', 'JJ'), ('resource', 'NN'), ('provisioning', 'VBG'), ('for', 'IN'), ('multi', 'JJ'), ('service', 'NN'), ('web', 'NN'), ('applications', 'NNS')]
# [('An', 'DT'), ('improved', 'JJ'), ('soft', 'JJ'), ('BCH', 'NNP'), ('decoder', 'NN'), ('with', 'IN'), ('one', 'CD'), ('extra', 'JJ'), ('error', 'NN'), ('compensation', 'NN')]
# [('Routing', 'VBG'), ('in', 'IN'), ('Overlay', 'NNP'), ('Multicast', 'NNP'), ('Networks', 'NNP')]
# [('A', 'DT'), ('Ku', 'NNP'), ('band', 'NN'), ('down', 'RP'), ('converter', 'NN'), ('with', 'IN'), ('perfect', 'JJ'), ('differential', 'JJ'), ('PLL', 'NNP'), ('in', 'IN'), ('um', 'JJ'), ('CMOS', 'NNP')]
# [('The', 'DT'), ('Design', 'NNP'), ('of', 'IN'), ('Symmetric', 'NNP'), ('Square', 'NNP'), ('Root', 'NNP'), ('Pulse', 'NNP'), ('Shaping', 'NNP'), ('Filters', 'NNP'), ('for', 'IN'), ('Transmitters', 'NNP'), ('and', 'CC'), ('Receivers', 'NNP')]
# [('Design', 'NN'), ('of', 'IN'), ('concurrent', 'NN'), ('multi', 'NN'), ('band', 'NN'), ('matching', 'VBG'), ('networks', 'NNS')]
# [('Just', 'RB'), ('the', 'DT'), ('right', 'JJ'), ('amount', 'NN'), ('extracting', 'VBG'), ('modules', 'NNS'), ('from', 'IN'), ('ontologies', 'NNS')]
# [('Distributed', 'VBN'), ('Querying', 'NNP'), ('of', 'IN'), ('Internet', 'NNP'), ('Distance', 'NNP'), ('Information', 'NN')]
# [('Non', 'NNP'), ('causal', 'NN'), ('error', 'NN'), ('control', 'NN'), ('for', 'IN'), ('wireless', 'JJ'), ('video', 'NN'), ('streaming', 'VBG'), ('with', 'IN'), ('noncoherent', 'JJ'), ('signaling', 'VBG')]
# [('Steel', 'NNP'), ('life', 'NN')]
# [('A', 'DT'), ('simulation', 'NN'), ('of', 'IN'), ('pearl', 'JJ'), ('optical', 'JJ'), ('phenomena', 'NN'), ('for', 'IN'), ('cosmetic', 'JJ'), ('preproduction', 'NN')]
# [('The', 'DT'), ('gRNA', 'NN'), ('A', 'NNP'), ('Highly', 'NNP'), ('Programmable', 'NNP'), ('Infrastructure', 'NN'), ('for', 'IN'), ('Prototyping', 'VBG'), ('Developing', 'NNP'), ('and', 'CC'), ('Deploying', 'NNP'), ('Genomics', 'NNP'), ('Centric', 'NNP'), ('Applications', 'NNP')]
# [('Foundations', 'NNS'), ('of', 'IN'), ('Uncertain', 'NNP'), ('Data', 'NNP'), ('Integration', 'NNP')]
# [('Progressive', 'JJ'), ('lossless', 'NN'), ('compression', 'NN'), ('of', 'IN'), ('arbitrary', 'JJ'), ('simplicial', 'NN'), ('complexes', 'NNS')]
# [('Potter', 'NNP'), ('s', 'NN'), ('Wheel', 'NNP'), ('An', 'DT'), ('Interactive', 'NNP'), ('Data', 'NNP'), ('Cleaning', 'NNP'), ('System', 'NNP')]
# [('Revisiting', 'VBG'), ('the', 'DT'), ('Absolutely', 'NNP'), ('Minimal', 'NNP'), ('Realization', 'NNP'), ('for', 'IN'), ('Two', 'CD'), ('dimensional', 'JJ'), ('Digital', 'NNP'), ('Filters', 'NNS')]
# [('Automated', 'VBN'), ('synthesis', 'NN'), ('of', 'IN'), ('executable', 'JJ'), ('web', 'JJ'), ('service', 'NN'), ('compositions', 'NNS'), ('from', 'IN'), ('BPEL', 'NNP'), ('WS', 'NNP'), ('processes', 'NNS')]
# [('Online', 'NNP'), ('Dynamic', 'NNP'), ('Reordering', 'NNP'), ('for', 'IN'), ('Interactive', 'NNP'), ('Data', 'NNP'), ('Processing', 'NNP')]
# [('An', 'DT'), ('Efficient', 'JJ'), ('Implementation', 'NN'), ('of', 'IN'), ('a', 'DT'), ('Relational', 'NNP'), ('Data', 'NNP'), ('Base', 'NNP')]
# [('A', 'DT'), ('Buyers', 'NNPS'), ('Integration', 'NNP'), ('Support', 'NNP'), ('System', 'NNP'), ('based', 'VBN'), ('on', 'IN'), ('Users', 'NNS'), ('Multi', 'NNP'), ('Attribute', 'NNP'), ('Utilities', 'NNP'), ('for', 'IN'), ('Internet', 'NNP'), ('Group', 'NNP'), ('Buying', 'NNP')]
# [('Making', 'VBG'), ('use', 'NN'), ('of', 'IN'), ('social', 'JJ'), ('media', 'NNS'), ('data', 'NNS'), ('in', 'IN'), ('public', 'JJ'), ('health', 'NN')]
# ...
# [('Ad', 'NNP'), ('hoc', 'NN'), ('ride', 'NN'), ('sharing', 'VBG'), ('application', 'NN'), ('using', 'VBG'), ('continuous', 'JJ'), ('SPARQL', 'NNP'), ('queries', 'NNS')]
# [('Static', 'JJ'), ('force', 'NN'), ('measurement', 'NN'), ('by', 'IN'), ('piezoelectric', 'JJ'), ('sensors', 'NNS')]
# [('On', 'IN'), ('ray', 'NN'), ('tracing', 'VBG'), ('parametric', 'JJ'), ('surfaces', 'NNS')]
# [('Data', 'NNP'), ('Models', 'NNP'), ('for', 'IN'), ('Secondary', 'NNP'), ('Storage', 'NNP'), ('Representations', 'NNP')]
# [('Maximizing', 'VBG'), ('the', 'DT'), ('Contact', 'NNP'), ('Opportunity', 'NNP'), ('for', 'IN'), ('Vehicular', 'NNP'), ('Internet', 'NNP'), ('Access', 'NNP')]
# [('Interactive', 'JJ'), ('exploratory', 'NN'), ('search', 'NN'), ('for', 'IN'), ('multi', 'JJ'), ('page', 'NN'), ('search', 'NN'), ('results', 'NNS')]
# [('A', 'DT'), ('double', 'JJ'), ('data', 'NN'), ('rate', 'NN'), ('DDR', 'NNP'), ('processing', 'NN'), ('in', 'IN'), ('memory', 'NN'), ('PIM', 'NNP'), ('device', 'NN'), ('with', 'IN'), ('wideword', 'NN'), ('floating', 'VBG'), ('point', 'NN'), ('capability', 'NN')]
# [('Mapping', 'VBG'), ('Moving', 'VBG'), ('Landscapes', 'NNP'), ('by', 'IN'), ('Mining', 'NNP'), ('Mountains', 'NNP'), ('of', 'IN'), ('Logs', 'NNP'), ('Novel', 'NNP'), ('Techniques', 'NNP'), ('for', 'IN'), ('Dependency', 'NNP'), ('Model', 'NNP'), ('Generation', 'NNP')]
# [('VoiKiosk', 'NNP'), ('increasing', 'VBG'), ('reachability', 'NN'), ('of', 'IN'), ('kiosks', 'NNS'), ('in', 'IN'), ('developing', 'VBG'), ('regions', 'NNS')]
# [('State', 'NN'), ('of', 'IN'), ('the', 'DT'), ('art', 'NN'), ('and', 'CC'), ('future', 'JJ'), ('directions', 'NNS'), ('of', 'IN'), ('high', 'JJ'), ('performance', 'NN'), ('all', 'DT'), ('digital', 'JJ'), ('frequency', 'NN'), ('synthesis', 'NN'), ('in', 'IN'), ('nanometer', 'NN'), ('CMOS', 'NNP')]
# [('Reproducing', 'VBG'), ('Color', 'NNP'), ('Images', 'NNP'), ('Using', 'NNP'), ('Custom', 'NNP'), ('Inks', 'NNP')]
# [('Multi', 'NNP'), ('color', 'NN'), ('and', 'CC'), ('Artistic', 'NNP'), ('Dithering', 'NNP')]
# [('A', 'DT'), ('Proposed', 'VBN'), ('AVS', 'NNP'), ('Decoder', 'NNP'), ('Configuration', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('Reconfigurable', 'JJ'), ('Video', 'NNP'), ('Coding', 'NNP'), ('Framework', 'NNP')]
# [('Extracting', 'VBG'), ('semantic', 'JJ'), ('structure', 'NN'), ('of', 'IN'), ('web', 'JJ'), ('documents', 'NNS'), ('using', 'VBG'), ('content', 'NN'), ('and', 'CC'), ('visual', 'JJ'), ('information', 'NN')]
# [('Economics', 'NNS'), ('of', 'IN'), ('BitTorrent', 'NNP'), ('communities', 'NNS')]
# [('Lossless', 'NNP'), ('Video', 'NNP'), ('Compression', 'NNP'), ('with', 'IN'), ('Residual', 'NNP'), ('Image', 'NNP'), ('prediction', 'NN'), ('and', 'CC'), ('Coding', 'NNP'), ('RIPC', 'NNP')]
# [('A', 'DT'), ('full', 'JJ'), ('differential', 'NN'), ('analog', 'NN'), ('design', 'NN'), ('of', 'IN'), ('an', 'DT'), ('indirect', 'JJ'), ('inverse', 'NN'), ('control', 'NN'), ('law', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('neural', 'JJ'), ('networks', 'NNS')]
# [('Cache', 'NNP'), ('Conscious', 'NNP'), ('Algorithms', 'NNP'), ('for', 'IN'), ('Relational', 'NNP'), ('Query', 'NNP'), ('Processing', 'NNP')]
# [('Constructing', 'VBG'), ('extensible', 'JJ'), ('XQuery', 'NN'), ('mappings', 'NNS')]
# [('A', 'DT'), ('nm', 'JJ'), ('Mb', 'NNP'), ('pipeline', 'NN'), ('T', 'NNP'), ('SRAM', 'NNP'), ('with', 'IN'), ('variation', 'NN'), ('tolerant', 'JJ'), ('Step', 'NNP'), ('Up', 'NNP'), ('Word', 'NNP'), ('Line', 'NNP'), ('and', 'CC'), ('Adaptive', 'NNP'), ('Data', 'NNP'), ('Aware', 'NNP'), ('Write', 'NNP'), ('Assist', 'NNP')]
# [('On', 'IN'), ('line', 'NN'), ('Lossless', 'NNP'), ('Mocap', 'NNP'), ('Data', 'NNP'), ('Compression', 'NNP')]
# [('Configurable', 'JJ'), ('and', 'CC'), ('ad', 'NN'), ('hoc', 'NN'), ('display', 'NN'), ('for', 'IN'), ('clothes', 'NNS')]
# [('Verifying', 'VBG'), ('Computations', 'NNS'), ('with', 'IN'), ('Streaming', 'NNP'), ('Interactive', 'NNP'), ('Proofs', 'NNP')]
# [('A', 'DT'), ('bit', 'NN'), ('low', 'JJ'), ('power', 'NN'), ('compact', 'NN'), ('ADC', 'NNP'), ('suitable', 'NN'), ('for', 'IN'), ('sensor', 'NN'), ('applications', 'NNS')]
# [('PageRank', 'NNP'), ('as', 'IN'), ('a', 'DT'), ('function', 'NN'), ('of', 'IN'), ('the', 'DT'), ('damping', 'NN'), ('factor', 'NN')]
# [('TextToSpeech', 'VB'), ('a', 'DT'), ('Heavy', 'NNP'), ('weight', 'NN'), ('Edge', 'NNP'), ('Service', 'NNP')]
# [('Low', 'JJ'), ('power', 'NN'), ('LDPC', 'NNP'), ('decoding', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('iteration', 'NN'), ('prediction', 'NN')]
# [('BPB', 'IN'), ('A', 'NNP'), ('Novel', 'NNP'), ('Approach', 'NNP'), ('for', 'IN'), ('Obtaining', 'NNP'), ('Network', 'NNP'), ('Path', 'NNP'), ('Characteristics', 'NNPS'), ('in', 'IN'), ('Non', 'NNP'), ('Cooperative', 'NNP'), ('Environments', 'NNS')]
# [('Rethinking', 'VBG'), ('Fourier', 'NNP'), ('s', 'NN'), ('legacy', 'NN'), ('in', 'IN'), ('signals', 'NNS'), ('and', 'CC'), ('systems', 'NNS'), ('education', 'NN')]
# [('A', 'DT'), ('micro', 'NN'), ('W', 'NNP'), ('Wake', 'NNP'), ('up', 'RP'), ('Receiver', 'NNP'), ('for', 'IN'), ('wireless', 'NN'), ('sensor', 'NN'), ('nodes', 'NNS'), ('with', 'IN'), ('dBm', 'JJ'), ('sensitivity', 'NN')]
# [('An', 'DT'), ('eigenvalue', 'JJ'), ('formulation', 'NN'), ('for', 'IN'), ('determining', 'VBG'), ('initial', 'JJ'), ('conditions', 'NNS'), ('of', 'IN'), ('induction', 'NN'), ('machines', 'NNS'), ('in', 'IN'), ('dynamic', 'JJ'), ('power', 'NN'), ('system', 'NN'), ('simulations', 'NNS')]
# [('Virtual', 'NNP'), ('Backbone', 'NNP'), ('Generation', 'NNP'), ('and', 'CC'), ('Maintenance', 'NNP'), ('in', 'IN'), ('Ad', 'NNP'), ('Hoc', 'NNP'), ('Network', 'NNP'), ('Mobility', 'NNP'), ('Management', 'NNP')]
# [('XVR', 'NN'), ('X', 'NNP'), ('visiting', 'VBG'), ('pattern', 'JJ'), ('routing', 'VBG'), ('for', 'IN'), ('sensor', 'NN'), ('networks', 'NNS')]
# [('Toward', 'NNP'), ('Practical', 'NNP'), ('Constraint', 'NNP'), ('Databases', 'NNP')]
# [('Generating', 'VBG'), ('hypotheses', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('web', 'NN')]
# [('Identifying', 'VBG'), ('mobiles', 'NNS'), ('hiding', 'VBG'), ('behind', 'IN'), ('wireless', 'NN'), ('routers', 'NNS')]
# [('Demonstration', 'NN'), ('of', 'IN'), ('the', 'DT'), ('FDB', 'NNP'), ('Query', 'NNP'), ('Engine', 'NNP'), ('for', 'IN'), ('Factorised', 'JJ'), ('Databases', 'NNS')]
# [('DF', 'NNP'), ('or', 'CC'), ('IDF', 'NNP'), ('On', 'IN'), ('the', 'DT'), ('Use', 'NNP'), ('of', 'IN'), ('HTML', 'NNP'), ('Primary', 'NNP'), ('Feature', 'NNP'), ('Fields', 'NNP'), ('for', 'IN'), ('Web', 'NNP'), ('IR', 'NNP')]
# [('Slicing', 'VBG'), ('Long', 'NNP'), ('Running', 'NNP'), ('Queries', 'NNS')]
# [('CacheMakers', 'NNS'), ('A', 'NNP'), ('Co', 'NNP'), ('operative', 'JJ'), ('DNS', 'NNP'), ('Caching', 'NNP'), ('Service', 'NNP')]
# [('Integrated', 'VBN'), ('low', 'JJ'), ('voltage', 'NN'), ('and', 'CC'), ('low', 'JJ'), ('power', 'NN'), ('CMOS', 'NNP'), ('circuits', 'NNS'), ('for', 'IN'), ('optical', 'JJ'), ('sensing', 'NN'), ('of', 'IN'), ('diffraction', 'NN'), ('based', 'VBN'), ('micromachined', 'VBD'), ('microphone', 'NN')]
# [('High', 'JJ'), ('bandwidth', 'NN'), ('power', 'NN'), ('scalable', 'JJ'), ('bit', 'NN'), ('pipelined', 'VBD'), ('ADC', 'NNP'), ('using', 'VBG'), ('bandwidth', 'JJ'), ('reconfigurable', 'JJ'), ('operational', 'JJ'), ('amplifier', 'NN')]
# [('Estimating', 'VBG'), ('Hop', 'NNP'), ('Distance', 'NNP'), ('Between', 'NNP'), ('Arbitrary', 'NNP'), ('Host', 'NNP'), ('Pairs', 'NNP')]
# [('Tile', 'NNP'), ('based', 'VBN'), ('GPU', 'NNP'), ('optimizations', 'NNS'), ('through', 'IN'), ('ESL', 'NNP'), ('full', 'JJ'), ('system', 'NN'), ('simulation', 'NN')]
# [('A', 'DT'), ('data', 'NN'), ('driven', 'NN'), ('sketch', 'NN'), ('of', 'IN'), ('Wikipedia', 'NNP'), ('editors', 'NNS')]
# [('Throughput', 'NNP'), ('Delay', 'NNP'), ('and', 'CC'), ('Mobility', 'NNP'), ('in', 'IN'), ('Wireless', 'NNP'), ('Ad', 'NNP'), ('Hoc', 'NNP'), ('Networks', 'NNP')]
# [('A', 'DT'), ('New', 'NNP'), ('Class', 'NNP'), ('based', 'VBN'), ('Early', 'JJ'), ('Termination', 'NNP'), ('Method', 'NNP'), ('for', 'IN'), ('Fast', 'NNP'), ('Motion', 'NNP'), ('Estimation', 'NNP'), ('in', 'IN'), ('Video', 'NNP'), ('Coding', 'NNP')]
# [('Object', 'JJ'), ('segmentation', 'NN'), ('from', 'IN'), ('wide', 'JJ'), ('baseline', 'NN'), ('video', 'NN')]
# [('Information', 'NN'), ('Processing', 'VBG'), ('for', 'IN'), ('CAD', 'NNP'), ('VLSI', 'NNP'), ('on', 'IN'), ('a', 'DT'), ('Generalized', 'NNP'), ('Data', 'NNP'), ('Management', 'NNP'), ('System', 'NNP')]
# [('Energy', 'NNP'), ('efficient', 'JJ'), ('broadcast', 'NN'), ('in', 'IN'), ('multiradio', 'NN'), ('multichannel', 'NN'), ('wireless', 'NN'), ('networks', 'NNS')]
# [('A', 'DT'), ('smart', 'JJ'), ('wireless', 'NN'), ('glove', 'NN'), ('for', 'IN'), ('gesture', 'NN'), ('interaction', 'NN')]
# [('Analyzing', 'VBG'), ('and', 'CC'), ('predicting', 'VBG'), ('viral', 'JJ'), ('tweets', 'NNS')]
# [('Efficient', 'JJ'), ('bump', 'NN'), ('mapping', 'NN'), ('hardware', 'NN')]
# [('Exploratory', 'JJ'), ('search', 'NN'), ('in', 'IN'), ('multi', 'NN'), ('domain', 'NN'), ('information', 'NN'), ('spaces', 'NNS'), ('with', 'IN'), ('liquid', 'JJ'), ('query', 'NN')]
# [('A', 'DT'), ('Capacitor', 'NNP'), ('free', 'JJ'), ('CMOS', 'NNP'), ('Low', 'NNP'), ('dropout', 'NN'), ('Voltage', 'NNP'), ('Regulator', 'NNP')]
# [('Using', 'VBG'), ('Compact', 'NNP'), ('GML', 'NNP'), ('to', 'TO'), ('Deploy', 'NNP'), ('Interactive', 'NNP'), ('Maps', 'NNP'), ('on', 'IN'), ('Mobile', 'NNP')]
# [('Analog', 'NNP'), ('complex', 'JJ'), ('gammatone', 'NN'), ('filter', 'NN'), ('for', 'IN'), ('cochlear', 'JJ'), ('implant', 'JJ'), ('channels', 'NNS')]
# [('Interference', 'NN'), ('analysis', 'NN'), ('on', 'IN'), ('Resonant', 'NNP'), ('Inductive', 'NNP'), ('Coupled', 'NNP'), ('Wireless', 'NNP'), ('Power', 'NNP'), ('Transfer', 'NNP'), ('links', 'NNS')]
# [('A', 'DT'), ('detection', 'NN'), ('method', 'NN'), ('of', 'IN'), ('nasalised', 'JJ'), ('vowels', 'NNS'), ('based', 'VBN'), ('on', 'IN'), ('an', 'DT'), ('acoustic', 'JJ'), ('parameter', 'NN'), ('derived', 'VBN'), ('from', 'IN'), ('phase', 'NN'), ('spectrum', 'NN')]
# [('Efficient', 'JJ'), ('multi', 'NN'), ('view', 'NN'), ('maintenance', 'NN'), ('in', 'IN'), ('the', 'DT'), ('social', 'JJ'), ('semantic', 'JJ'), ('web', 'NN')]
# [('On', 'IN'), ('Semantic', 'NNP'), ('Issues', 'NNP'), ('Connected', 'NNP'), ('with', 'IN'), ('Incomplete', 'NNP'), ('Information', 'NNP'), ('Data', 'NNP'), ('Bases', 'NNP'), ('Abstract', 'NNP')]
# [('Features', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('Conceptual', 'NNP'), ('Schema', 'NNP')]
# [('Specifying', 'VBG'), ('and', 'CC'), ('Enforcing', 'NNP'), ('Intertask', 'NNP'), ('Dependencies', 'NNP')]
# [('VLSI', 'NNP'), ('decoding', 'VBG'), ('architecture', 'NN'), ('with', 'IN'), ('improved', 'JJ'), ('convergence', 'NN'), ('speed', 'NN'), ('and', 'CC'), ('reduced', 'VBD'), ('decoding', 'VBG'), ('latency', 'NN'), ('for', 'IN'), ('irregular', 'JJ'), ('LDPC', 'NNP'), ('codes', 'NNS'), ('in', 'IN'), ('WiMAX', 'NNP')]
# [('Detecting', 'VBG'), ('the', 'DT'), ('origin', 'NN'), ('of', 'IN'), ('text', 'JJ'), ('segments', 'NNS'), ('efficiently', 'RB')]
# [('Delay', 'NNP'), ('Tolerant', 'NNP'), ('Event', 'NNP'), ('Collection', 'NNP'), ('in', 'IN'), ('Sensor', 'NNP'), ('Networks', 'NNP'), ('with', 'IN'), ('Mobile', 'NNP'), ('Sink', 'NNP')]
# [('Active', 'JJ'), ('noise', 'NN'), ('cancellation', 'NN'), ('of', 'IN'), ('motion', 'NN'), ('artifacts', 'NNS'), ('in', 'IN'), ('pulse', 'JJ'), ('oximetry', 'NN'), ('using', 'VBG'), ('isobestic', 'JJ'), ('wavelength', 'NN'), ('light', 'VBD'), ('source', 'NN')]
# [('User', 'NNP'), ('Centered', 'NNP'), ('Modeling', 'NNP'), ('of', 'IN'), ('Interactive', 'NNP'), ('Web', 'NNP'), ('Sites', 'NNP')]
# [('Automatic', 'JJ'), ('matchmaking', 'NN'), ('of', 'IN'), ('web', 'NN'), ('services', 'NNS')]
# [('Structural', 'JJ'), ('analysis', 'NN'), ('of', 'IN'), ('the', 'DT'), ('emerging', 'VBG'), ('event', 'NN'), ('web', 'NN')]
# [('When', 'WRB'), ('Speed', 'NNP'), ('Has', 'VBZ'), ('a', 'DT'), ('Price', 'NNP'), ('Fast', 'NNP'), ('Information', 'NNP'), ('Extraction', 'NNP'), ('Using', 'NNP'), ('Approximate', 'NNP'), ('Algorithms', 'NNP')]
# [('Capturing', 'VBG'), ('Global', 'JJ'), ('Transactions', 'NNS'), ('from', 'IN'), ('Multiple', 'JJ'), ('Recovery', 'NNP'), ('Log', 'NNP'), ('Files', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('Partitioned', 'NNP'), ('Database', 'NNP'), ('System', 'NNP')]
# [('TELEIOS', 'VB'), ('A', 'DT'), ('Database', 'NNP'), ('Powered', 'NNP'), ('Virtual', 'NNP'), ('Earth', 'NNP'), ('Observatory', 'NNP')]
# [('Analysis', 'NN'), ('and', 'CC'), ('design', 'NN'), ('of', 'IN'), ('a', 'DT'), ('loss', 'NN'), ('free', 'JJ'), ('resistor', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('a', 'DT'), ('boost', 'NN'), ('converter', 'NN'), ('in', 'IN'), ('PWM', 'NNP'), ('operation', 'NN')]
# [('Deformation', 'NNP'), ('transfer', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('stretchiness', 'NN'), ('ratio', 'NN')]
# [('How', 'WRB'), ('to', 'TO'), ('make', 'VB'), ('web', 'NN'), ('sites', 'NNS'), ('talk', 'VBP'), ('together', 'RB'), ('web', 'JJ'), ('service', 'NN'), ('solution', 'NN')]
# [('Trapping', 'VBG'), ('region', 'NN'), ('for', 'IN'), ('the', 'DT'), ('double', 'JJ'), ('scroll', 'NN'), ('attractor', 'NN')]
# [('METEOR', 'NNP'), ('metadata', 'NN'), ('and', 'CC'), ('instance', 'NN'), ('extraction', 'NN'), ('from', 'IN'), ('object', 'JJ'), ('referral', 'JJ'), ('lists', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('web', 'NN')]
# [('Program', 'NN'), ('notes', 'NNS')]
# [('An', 'DT'), ('Improved', 'NNP'), ('method', 'NN'), ('for', 'IN'), ('the', 'DT'), ('design', 'NN'), ('of', 'IN'), ('variable', 'JJ'), ('fractional', 'JJ'), ('delay', 'NN'), ('IIR', 'NNP'), ('digital', 'JJ'), ('filters', 'NNS')]
# [('Failure', 'NN'), ('Control', 'NNP'), ('in', 'IN'), ('Multipath', 'NNP'), ('Route', 'NNP'), ('Tracing', 'NNP')]
# [('On', 'IN'), ('the', 'DT'), ('degree', 'NN'), ('of', 'IN'), ('MIMO', 'NNP'), ('systems', 'NNS')]
# [('On', 'IN'), ('the', 'DT'), ('level', 'NN')]
# [('A', 'DT'), ('hybrid', 'JJ'), ('approach', 'NN'), ('for', 'IN'), ('spotting', 'VBG'), ('disambiguating', 'NN'), ('and', 'CC'), ('annotating', 'VBG'), ('places', 'NNS'), ('in', 'IN'), ('user', 'NN'), ('generated', 'VBD'), ('text', 'NN')]
# [('How', 'WRB'), ('Best', 'JJS'), ('to', 'TO'), ('Build', 'VB'), ('Web', 'NNP'), ('Scale', 'NNP'), ('Data', 'NNP'), ('Managers', 'NNP'), ('A', 'NNP'), ('Panel', 'NNP'), ('Discussion', 'NN')]
# [('Hybrid', 'NNP'), ('CMOS', 'NNP'), ('memristor', 'NN'), ('circuits', 'NNS')]
# [('Home', 'NNP'), ('grown', 'NN'), ('CGI', 'NNP'), ('the', 'DT'), ('cultivation', 'NN'), ('of', 'IN'), ('Henry', 'NNP'), ('s', 'NNP'), ('Garden', 'NNP')]
# [('What', 'WP'), ('you', 'PRP'), ('see', 'VBP'), ('is', 'VBZ'), ('what', 'WP'), ('you', 'PRP'), ('search', 'VBP'), ('adaptive', 'JJ'), ('visual', 'JJ'), ('search', 'NN'), ('framework', 'NN'), ('for', 'IN'), ('the', 'DT'), ('web', 'NN')]
# [('A', 'DT'), ('Switched', 'NNP'), ('Capacitor', 'NNP'), ('Implementation', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Generalized', 'NNP'), ('Linear', 'NNP'), ('Integrate', 'NNP'), ('and', 'CC'), ('fire', 'NN'), ('Neuron', 'NNP')]
# [('ViBE', 'NNP'), ('virtual', 'JJ'), ('biology', 'NN'), ('experiments', 'NNS')]
# [('A', 'DT'), ('new', 'JJ'), ('QR', 'NNP'), ('decomposition', 'NN'), ('based', 'VBN'), ('recursive', 'JJ'), ('frequency', 'NN'), ('estimator', 'NN'), ('for', 'IN'), ('multiple', 'JJ'), ('sinusoids', 'NNS'), ('in', 'IN'), ('impulsive', 'JJ'), ('noise', 'NN'), ('environment', 'NN')]
# [('CNN', 'NNP'), ('Implementation', 'NNP'), ('of', 'IN'), ('Spin', 'NNP'), ('Filters', 'NNP'), ('for', 'IN'), ('Electronic', 'NNP'), ('Speckle', 'NNP'), ('Pattern', 'NNP'), ('Interferometry', 'NNP'), ('Applications', 'NNS')]
# [('FaceKit', 'NNP'), ('A', 'NNP'), ('Database', 'NNP'), ('Interface', 'NNP'), ('Design', 'NNP'), ('Toolkit', 'NNP')]
# [('On', 'IN'), ('the', 'DT'), ('trade', 'NN'), ('off', 'IN'), ('between', 'IN'), ('the', 'DT'), ('number', 'NN'), ('of', 'IN'), ('scrolls', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('operating', 'NN'), ('frequency', 'NN'), ('of', 'IN'), ('the', 'DT'), ('chaotic', 'JJ'), ('attractors', 'NNS')]
# [('Tracing', 'VBG'), ('Ray', 'NNP'), ('Differentials', 'NNS')]

# %%
vectoriser = TfidfVectorizer(token_pattern=r'[a-z]+', min_df=5, max_df=.95, stop_words = stop_words)
vectoriser.fit_transform(data['Title'])
tokens = list(vectoriser.vocabulary_.keys())

# %%
def categorize_data_class_wise(data):
    classes = list(data['Conference'].unique())
    data_class_wise = {cls:data.groupby(['Conference']).get_group(cls)['Title'].tolist() for cls in data['Conference'].unique()}
    return data_class_wise

# %%
def marginal_count_of_word(data, word):
    return data.loc[[ word in word_set
        for word_set in (set(words) for words in
                         data['Title']
                         .str.strip()
                         .str.split())], :].shape[0]
marginal_count_of_word(data, 'database')
# Out:
# 90

# %%
def marginal_count_of_class(data, cls, data_class_wise):
    return len(data_class_wise[cls])

# %%
print('ndot1: ', marginal_count_of_class(data, 'VLDB', data_class_wise))
# Out:
# ndot1:  423

# %%
def joint_count(word, cls, data_class_wise):
    count = 0
    to_match = []
    class_data =data_class_wise[cls]
    class_data = pd.DataFrame(data_class_wise[cls], columns = ['Title'])
    return marginal_count_of_word(class_data, word)

# %%
data_class_wise =categorize_data_class_wise(data)

# %%
def mutual_info(word,cls, data, data_class_wise):
    # print(word)
    mi = 0
    n = data.shape[0]
    n11 = joint_count(word,cls, data_class_wise)
    # print(n11)
    ndot1 = marginal_count_of_class(data, cls, data_class_wise)
    # print('ndot1: ', ndot1)
    n1dot = marginal_count_of_word(data, word)   
    # print('n1dot: ', n1dot)
    n10 = n1dot - n11
    # print('n10: ', n10)
    n01 = ndot1 -n11
    # print('n01: ', n01)
    # print(f'n10: {n10} and n01: {n01}')
    n00 = n - (n11 + n01 + n10)
    # print('n00: ', n00)
    n0dot = n01 + n00
    ndot0 = n10 + n00
    keys = [n11, n10, n01, n00]
    # print(keys)
    values = [[ndot1, n1dot], [n1dot, ndot0], [n0dot, ndot1], [n0dot, ndot0]]
    vals = {}                              
    for i, key in enumerate(keys):                  
        vals.setdefault(key, []).append(values[i])   
    # print(vals)
    for key in vals:
        for i in range(len(vals[key])):
            li = vals[key][i]
            den = li[0] * li[1]
            num = key * n
            if num == 0:
                mi+=0
            else:
                mi+= key/n * log2(num/den)
    return mi

# %%
mutual_info('database','VLDB', data, data_class_wise) #ndot1 = n01 +n11()
# Out:
# 0.08354739627654717

# %%
# n11 is the number of documents that contain 'database' and are classified as 'VLDB':
df = data[data['Conference'] == 'VLDB']
df.reset_index(drop = True, inplace = True)

df = df.loc[['database' in word_set
        for word_set in (set(words) for words in
                         df['Title']
                         .str.strip()
                         .str.split())], :]
count = df.shape[0]
print('n11:',count)
n11 = count
# Out:
# n11: 86

# %%
# n10 is the number of documents that contain 'database' and are not in class 'VLDB':
df = data[data['Conference'] != 'VLDB']
df.reset_index(drop = True, inplace = True)

df = df.loc[['database' in word_set
        for word_set in (set(words) for words in
                         df['Title']
                         .str.strip()
                         .str.split())], :]
count = df.shape[0]
print('n10:',count)
n10 = count
# Out:
# n10: 4

# %%
# n01 is the number of documents classified as class 'VLDB' that does not contain  word 'database':
df = data[data['Conference'] == 'VLDB']
df.reset_index(drop = True, inplace = True)
df = df.loc[['database' not in word_set
        for word_set in (set(words) for words in
                         df['Title']
                         .str.strip()
                         .str.split())], :]
count = df.shape[0]
print('n01:',count)
n01 = count
# Out:
# n01: 337

# %%
# ndot1, count of the documents containing the class:
ndot1 = data[data['Conference']=='VLDB'].shape[0]
print('ndot1:', ndot1)
# Out:
# ndot1: 423

# %%
#n00 is the count of the documents without term 'database' and not belonging to class 'VLDB'
df = data[data['Conference'] != 'VLDB']
df.reset_index(drop = True, inplace = True)
df = df.loc[['database' not in word_set
        for word_set in (set(words) for words in
                         df['Title']
                         .str.strip()
                         .str.split())], :]
count = df.shape[0]
print('n00:',count)
n00 = count
# Out:
# n00: 2080

# %%
# n0dot is the number of document without term 'database':
count = 0
df = data.loc[['database' not in word_set
        for word_set in (set(words) for words in
                         data['Title']
                         .str.lower()
                         .str.strip()
                         .str.split())], :]
count = df.shape[0]
print('n0dot:', count)
# Out:
# n0dot: 2417

# %%
# ndot0 is the number of documents that do not belong to class 'VLDB':
print('ndot0:', data[data['Conference'] != 'VLDB'].shape[0])
# Out:
# ndot0: 2084

# %%
def calc_mutual_info(Total_words):
    classes = list(data['Conference'].unique())
    mi_data = {}
    for cls in classes:
        print(cls)
        mi_data[cls]= [mutual_info(word, cls, data, data_class_wise) for word in Total_words]
    return mi_data

# %%
mi_data = calc_mutual_info(tokens)
# Out:
# VLDB
# ISCAS
# SIGGRAPH
# INFOCOM
# WWW

# %%
df = pd.DataFrame(data = mi_data, index = tokens, columns = list(data['Conference'].unique()))
df.to_excel('MI_data.xlsx')

# %%
def select_top_k_words(k, mi_data, words):
    classes = list(data['Conference'].unique())
    df = pd.DataFrame(data = mi_data, index = words, columns = classes )
    best_k = {}
    for cls in classes:
        best_k[cls] = df[cls].sort_values(ascending = False).head(k).index.tolist()
        print(cls, best_k[cls])
    return best_k

# %%
best_k = select_top_k_words(20, mi_data, tokens)
# Out:
# VLDB ['database', 'data', 'query', 'network', 'relational', 'index', 'wireless', 'power', 'join', 'schema', 'management', 'cmos', 'processing', 'sql', 'low', 'issue', 'dbms', 'circuit', 'xml', 'top']
# ISCAS ['cmos', 'low', 'web', 'power', 'circuit', 'network', 'converter', 'query', 'filter', 'amplifier', 'voltage', 'noise', 'database', 'design', 'delta', 'mode', 'sigma', 'high', 'frequency', 'data']
# SIGGRAPH ['network', 'animation', 'surface', 'graphic', 'light', 'display', 'reality', 'power', 'computer', 'low', 'wireless', 'rendering', 'web', 'render', 'texture', 'image', 'panel', 'interactive', 'cmos', 'radiosity']
# INFOCOM ['network', 'wireless', 'routing', 'hoc', 'packet', 'hop', 'sensor', 'ad', 'ip', 'web', 'database', 'multicast', 'optimal', 'qos', 'scheduling', 'cmos', 'schedule', 'rout', 'image', 'congestion']
# WWW ['web', 'search', 'semantic', 'social', 'wireless', 'rank', 'low', 'topic', 'power', 'service', 'cmos', 'recommendation', 'information', 'user', 'news', 'engine', 'network', 'click', 'document', 'sensor']

# %%
import csv
w = csv.writer(open("SelectKBest(Mutual_Info).csv", "w"))
for key, val in best_k.items():
    w.writerow([key, val])
